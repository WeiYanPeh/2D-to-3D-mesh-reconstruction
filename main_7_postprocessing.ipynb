# %%
# !pip3 install open3d --break-system-packages
# !pip3 install plyfile --break-system-packages
# !pip3 install pyntcloud --break-system-packages

# %%
# !pip3 list

# %%
# !pip3 uninstall -y meshlib --break-system-packages
# !pip3 uninstall -y SQLAlchemy --break-system-packages
# !pip3 uninstall -y sqlglot sqlglotrs --break-system-packages
# !pip3 uninstall -y rfc3986-validator rfc3339-validator --break-system-packages
# !pip3 uninstall -y PyWavelets --break-system-packages
# !pip3 uninstall -y numba --break-system-packages
# !pip3 uninstall -y numpy pandas

# %%
# !pip3 install numpy==1.26.4 pandas==2.2.2 --break-system-packages

# %% [markdown]
# # Import Library

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

import os
import sys
import ast
import copy

import numpy as np
np.set_printoptions(suppress=True)

import pandas as pd
import open3d as o3d
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from plyfile import PlyData, PlyElement
from collections import Counter

from scipy.spatial import ConvexHull
from scipy.spatial import cKDTree
from pyntcloud import PyntCloud

from Utilities.utilities import read_points3D, write_ply, calculate_volume, calculate_volume_file
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# # Function Plot

# %%
def plot_mesh(mesh):
    vertices = np.asarray(mesh.vertices)
    
    # Plot the PLY file
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(vertices[:, 0], vertices[:, 1], vertices[:, 2], s=0.005)
    
    # Set axis labels
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Z axis')
    # Set title
    ax.set_title('3D Mesh Plot')

    plt.show()
    return None

# %% [markdown]
# # User Defined Function

# %%
#################################################
# Remove isolated mesh
#################################################
def remove_isolated_vertices(mesh, eps=1.0, min_points=10):
    print("\nRemoving isolated vertices using DBSCAN clustering")

    # Convert mesh to point cloud
    pcd = o3d.geometry.PointCloud()
    pcd.points = mesh.vertices

    # Apply DBSCAN clustering
    labels = np.array(pcd.cluster_dbscan(eps=eps, min_points=min_points, print_progress=False))

    # Keep only the largest cluster
    largest_cluster = np.argmax(np.bincount(labels[labels >= 0]))
    mask = labels == largest_cluster

    # Map old indices to new indices
    index_map = -np.ones(len(mask), dtype=int)
    index_map[mask] = np.arange(np.sum(mask))

    # Filter vertices
    filtered_vertices = np.asarray(mesh.vertices)[mask]

    # Filter triangles
    triangles = np.asarray(mesh.triangles)
    filtered_triangles = []
    for tri in triangles:
        if np.all(mask[tri]):
            filtered_triangles.append(index_map[tri])

    # Create cleaned mesh
    cleaned_mesh = o3d.geometry.TriangleMesh()
    cleaned_mesh.vertices = o3d.utility.Vector3dVector(filtered_vertices)
    cleaned_mesh.triangles = o3d.utility.Vector3iVector(filtered_triangles)

    print(f"Remaining vertices: {len(filtered_vertices)}")
    return cleaned_mesh

# %%
#################################################
# Shift to positive
#################################################
def shift_to_positive(mesh):
    vertices = np.asarray(mesh.vertices)
    min_coords = vertices.min(axis=0)
    shifted_vertices = vertices - min_coords # shift so that min_coords becomes (0, 0, 0)
    
    # shift = np.abs(np.minimum(min_coords, 0))
    # shifted_vertices = vertices + shift

    shifted_mesh = o3d.geometry.TriangleMesh()
    shifted_mesh.vertices = o3d.utility.Vector3dVector(shifted_vertices)
    shifted_mesh.triangles = mesh.triangles

    return shifted_mesh

# %%
#################################################
# Reorientate Mesh (kinda works)
#################################################
def find_floor_plane_and_reorient(mesh, iteration=10):
    print(f'\nLocating floor plane and reorientate to x-y plane')

    for i in range(iteration):
        # Convert mesh vertices to numpy array
        points = np.asarray(mesh.vertices)

        # Create a PointCloud object from the mesh vertices
        point_cloud = o3d.geometry.PointCloud()
        point_cloud.points = o3d.utility.Vector3dVector(points)

        # Use RANSAC to find the plane in the point cloud
        plane_model, inliers = point_cloud.segment_plane(
            distance_threshold=0.01,
            ransac_n=3,
            num_iterations=1000)
        
        # Extract the plane coefficients
        a, b, c, d = plane_model
        
        # Calculate the normal vector of the plane
        normal_vector = np.array([a, b, c])
        
        # Calculate the rotation matrix to align the normal vector with the z-axis
        z_axis = np.array([0, 0, 1])
        rotation_axis = np.cross(normal_vector, z_axis)
        rotation_angle = np.arccos(np.dot(normal_vector, z_axis))
        rotation_matrix = o3d.geometry.get_rotation_matrix_from_axis_angle(
            rotation_axis * rotation_angle)
        
        # Rotate the mesh
        mesh.rotate(rotation_matrix, center=(0, 0, 0))
        
        # Translate the mesh to ensure the center of the floor is at (0, 0, 0)
        points = np.asarray(mesh.vertices)

        floor_center = points[inliers].mean(axis=0)
        translation_vector = -floor_center
        mesh.translate(translation_vector)
        
        # Ensure all points are on the positive side of z-axis by rotating about the x-y plane
        points = np.asarray(mesh.vertices)

        min_z = points[:, 2].min()
        if min_z < 0:
            rotation_matrix = o3d.geometry.get_rotation_matrix_from_xyz([np.pi, 0, 0])
            mesh.rotate(rotation_matrix, center=(0, 0, 0))
        
        # To handle mesh and point cloud
        mean_z = np.mean(np.asarray(mesh.vertices)[:, 2]) 
        if mean_z < 0:
            rotation_matrix = o3d.geometry.get_rotation_matrix_from_xyz([np.pi, 0, 0])
            mesh.rotate(rotation_matrix, center=(0, 0, 0))
            
        # print(f'Rotation {i+1}')
        # print(np.round(rotation_matrix), 5)
        # print(rotation_matrix)
        
    print(f'No of points: {len(np.asarray(mesh.vertices))}')
        
    return mesh

# %%
#################################################
# Remove floor
#################################################
def crop_mesh_z_axis(mesh, percentile=10):
    print('\nCropping mesh below the bottom 10th percentile of Z values')

    # Convert mesh vertices to numpy array
    points = np.asarray(mesh.vertices)
    triangles = np.asarray(mesh.triangles)

    # Calculate Z range and threshold
    z_values = points[:, 2]
    z_min, z_max = np.min(z_values), np.max(z_values)
    z_range = z_max - z_min
    z_threshold = z_min + percentile / 100 * z_range # bottom 10% threshold

    # Create a mask to keep points with Z >= threshold
    mask = z_values >= z_threshold

    # Map old indices to new indices
    index_map = -np.ones(len(points), dtype=int)
    index_map[mask] = np.arange(np.sum(mask))

    # Filter points
    filtered_points = points[mask]

    # Filter triangles: keep only those where all vertices are retained
    filtered_triangles = []
    for triangle in triangles:
        if np.all(mask[triangle]):
            new_triangle = index_map[triangle]
            filtered_triangles.append(new_triangle)

    # Create a new mesh
    cropped_mesh = o3d.geometry.TriangleMesh()
    cropped_mesh.vertices = o3d.utility.Vector3dVector(filtered_points)
    cropped_mesh.triangles = o3d.utility.Vector3iVector(filtered_triangles)

    print(f'No of points: {len(filtered_points)}')
    return cropped_mesh

# %%
#################################################
# Remove smallest objects
#################################################
def remove_small_objects(mesh):
    print(f'\nPerform mesh clustering to remove small objects')
    
    # Convert mesh vertices to numpy array
    points = np.asarray(mesh.vertices)
    triangles = np.asarray(mesh.triangles)
    
    # Create a PointCloud object from the mesh vertices
    point_cloud = o3d.geometry.PointCloud()
    point_cloud.points = o3d.utility.Vector3dVector(points)
    
    print('Range:', point_cloud.get_max_bound() - point_cloud.get_min_bound())
    
    # Cluster the points using DBSCAN algorithm
    eps = 0.1 # 0.01 (all noise)
    min_points = 10
    print('eps:', eps)
    print('min_points', min_points)    
    
    labels = np.array(point_cloud.cluster_dbscan(eps=eps,
                                                    min_points=min_points,
                                                    print_progress=True))
    
    print('Counter:')
    print(Counter(labels))
    
    # Check the number of clusters
    num_clusters = len(set(labels)) - (1 if -1 in labels else 0)
    
    # If only one cluster, return the one
    if num_clusters <= 1:
        print('Only 1 cluster found!')
        print(f'No of points: {len(np.asarray(mesh.vertices))}')
        return mesh
    
    print(f'{num_clusters} cluster found!')
    
    # Find the largest cluster
    largest_cluster_label = np.argmax(np.bincount(labels[labels >= 0]))
    
    # Create a mask to filter out points that are not in the largest cluster
    mask = labels == largest_cluster_label
    
    # Apply the mask to get the filtered points
    filtered_points = points[mask]
    
    # Remap the indices of the triangles to the filtered points
    index_map = np.zeros(len(points), dtype=int) - 1
    index_map[mask] = np.arange(np.sum(mask))
    filtered_triangles = []
    for triangle in triangles:
        if np.all(triangle < len(mask)) and np.all(mask[triangle]):
            filtered_triangles.append(index_map[triangle])
    
    # Create a new mesh with the filtered points and triangles
    largest_object_mesh = o3d.geometry.TriangleMesh()
    largest_object_mesh.vertices = o3d.utility.Vector3dVector(filtered_points)
    largest_object_mesh.triangles = o3d.utility.Vector3iVector(filtered_triangles)
    
    # If the amount of mesh removed is over 10% of the original mesh, stop the removal process    
    if len(np.asarray(largest_object_mesh.vertices)) * 10 < len(np.asarray(mesh.vertices)):
        print(f'Too many points are removed! Undo step')
        print(f'New - No of points: {len(np.asarray(largest_object_mesh.vertices))}')
        print(f'Old - No of points: {len(np.asarray(mesh.vertices))}')
        return mesh
    
    print(f'No of points: {len(np.asarray(largest_object_mesh.vertices))}')
    
    return largest_object_mesh

# %%
#################################################
# Rescaling based on foot
#################################################
def get_distance(x1, y1, x2, y2):
    distance = ((x1 - x2)**2 + (y1 - y2)**2)**0.5
    return distance
    

def scale_longest_xy_axis(mesh, target_length, percentile=100):
    print(f'\nScaling longest x-y axis based on foot length: {target_length}cm')

    points = np.asarray(mesh.vertices)
    z_threshold = np.percentile(points[:, 2], percentile)
    bottom_points = points[points[:, 2] <= z_threshold]

    # Get bounding box in x-y plane
    x_min, y_min = np.min(bottom_points[:, :2], axis=0)
    x_max, y_max = np.max(bottom_points[:, :2], axis=0)

    p_min = np.array([x_min, y_min, 0])
    p_max = np.array([x_max, y_max, 0])

    # Estimate longest distance as diagonal of bounding box
    p1x = (x_max + x_min) / 2
    p1y = y_min
    
    p2x = (x_max + x_min) / 2
    p2y = y_max
    
    p3x = x_min
    p3y = (y_max + y_min) / 2
    
    p4x = x_max
    p4y = (y_max + y_min) / 2
    
    l1 = get_distance(p1x, p1y, p2x, p2y)
    l2 = get_distance(p3x, p3y, p4x, p4y)

    # Get max distance
    if l1 > l2:    
        longest_distance = l1
    else:
        longest_distance = l2

    scale_factor = target_length / longest_distance #* 1.2 #* np.sqrt(2)
    print(f'Scaling Factor: {round(scale_factor, 1)} - Estimated Distance: {round(longest_distance, 1)} - Target Length: {target_length}')

    # Get points
    if l1 > l2:    
        point1 = np.array([p1x * scale_factor, p1y * scale_factor, 0])
        point2 = np.array([p2x * scale_factor, p2y * scale_factor, 0])
    else:
        point1 = np.array([p3x * scale_factor, p3y * scale_factor, 0])
        point2 = np.array([p4x * scale_factor, p4y * scale_factor, 0])

    p_min = np.array([x_min * scale_factor, y_min * scale_factor, 0])
    p_max = np.array([x_max * scale_factor, y_max * scale_factor, 0])

    points *= scale_factor
    mesh.vertices = o3d.utility.Vector3dVector(points)

    print(f'No of points: {len(points)}')
    return mesh, point1, point2, p_min, p_max

# %%
#################################################
# Reorientate foot (Take previous 2 points to orientate)
#################################################
def reorient_foot(mesh, point1, point2, target_direction=np.array([0, 1])):
    print(f'\nReorientate foot based on foot direction')
    
    points = np.asarray(mesh.vertices)

    # Compute the direction vector from point1 to point2 in the x-y plane
    direction_vector = point2[:2] - point1[:2]
    direction_vector /= np.linalg.norm(direction_vector)  # Normalize

    # Compute angle to target direction
    angle = np.arccos(np.dot(direction_vector, target_direction))

    # Determine rotation direction using cross product
    if np.cross(direction_vector, target_direction) < 0:
        angle = -angle

    # Rotation matrix around z-axis
    R = np.array([
        [np.cos(angle), -np.sin(angle), 0],
        [np.sin(angle),  np.cos(angle), 0],
        [0,              0,             1]
    ])

    # Apply rotation
    rotated_points = points @ R.T
    mesh.vertices = o3d.utility.Vector3dVector(rotated_points)
    
    print(f'No of points: {len(np.asarray(mesh.vertices))}')
    
    return mesh

# %%
# #################################################
# # Crop Ankle
# #################################################
# def crop_mesh_z_axis_ankle(mesh, z_threshold = 10):
#     print(f'\nCropping mesh from the top to make it {z_threshold}cm')

#     # Convert mesh vertices to numpy array
#     points = np.asarray(mesh.vertices)
#     triangles = np.asarray(mesh.triangles)
    
#     max_value = np.max(points[:, 2])
#     print('Max value:', max_value)
    
#     if max_value < z_threshold:
#         print(f'No of points: {len(np.asarray(mesh.vertices))}')
#         return mesh
    
#     else:
#         # Create a mask to filter out points below the z_threshold
#         mask = points[:, 2] < z_threshold
        
#         # Apply the mask to get the filtered points and update the triangles accordingly
#         filtered_points = points[mask]
#         filtered_triangles = []
#         for triangle in triangles:
#             if np.all(mask[triangle]):
#                 filtered_triangles.append(triangle)
        
#         # Create a new mesh with the filtered points and triangles
#         cropped_mesh = o3d.geometry.TriangleMesh()
#         cropped_mesh.vertices = o3d.utility.Vector3dVector(filtered_points)
#         cropped_mesh.triangles = o3d.utility.Vector3iVector(filtered_triangles)
        
#         print(f'No of points: {len(np.asarray(cropped_mesh.vertices))}')
#         return cropped_mesh

# %%
#################################################
#  Crop Ankle
#################################################
def crop_mesh_z_axis_ankle(mesh, z_threshold=10):
    print(f'\nCropping mesh from the top')

    # Convert mesh vertices to numpy array
    points = np.asarray(mesh.vertices)
    triangles = np.asarray(mesh.triangles)

    max_value = np.max(points[:, 2])
    print('Max value:', max_value)
    
    if max_value < z_threshold:
        print(f'No of points: {len(np.asarray(mesh.vertices))}')
        return mesh

    # Create a mask to keep points with Z >= threshold
    mask = points[:, 2] < z_threshold

    # Map old indices to new indices
    index_map = -np.ones(len(points), dtype=int)
    index_map[mask] = np.arange(np.sum(mask))

    # Filter points
    filtered_points = points[mask]

    # Filter triangles: keep only those where all vertices are retained
    filtered_triangles = []
    for triangle in triangles:
        if np.all(mask[triangle]):
            new_triangle = index_map[triangle]
            filtered_triangles.append(new_triangle)

    # Create a new mesh
    cropped_mesh = o3d.geometry.TriangleMesh()
    cropped_mesh.vertices = o3d.utility.Vector3dVector(filtered_points)
    cropped_mesh.triangles = o3d.utility.Vector3iVector(filtered_triangles)

    print(f'No of points: {len(filtered_points)}')
    return cropped_mesh

# %%
#################################################
# Solid mesh
#################################################
def solidify_mesh_with_fans(mesh, z_min=0.0, z_max=10.0):
    print(f'\nSolidify mesh')
    points = np.asarray(mesh.vertices)
    triangles = np.asarray(mesh.triangles)

    # Keep only points within the z bounds
    mask = (points[:, 2] >= z_min) & (points[:, 2] <= z_max)
    valid_indices = np.where(mask)[0]
    index_map = {old_idx: new_idx for new_idx, old_idx in enumerate(valid_indices)}
    filtered_points = points[mask]

    # Remap triangle indices
    filtered_triangles = []
    for tri in triangles:
        if all(idx in index_map for idx in tri):
            new_tri = [index_map[idx] for idx in tri]
            filtered_triangles.append(new_tri)

    cap_triangles = []

    # Cap both ends using triangle fans
    for z_target in [z_min, z_max]:
        cap_indices = np.where(np.isclose(filtered_points[:, 2], z_target))[0]
        if len(cap_indices) >= 3:
            cap_ring = filtered_points[cap_indices]
            center = np.mean(cap_ring, axis=0)
            center_idx = len(filtered_points)
            filtered_points = np.vstack([filtered_points, center])

            # Sort cap points in counter-clockwise order
            xy = cap_ring[:, :2] - center[:2]
            angles = np.arctan2(xy[:, 1], xy[:, 0])
            sorted_indices = cap_indices[np.argsort(angles)]

            for i in range(len(sorted_indices)):
                i1 = sorted_indices[i]
                i2 = sorted_indices[(i + 1) % len(sorted_indices)]
                if z_target == z_min:
                    cap_triangles.append([i1, i2, center_idx])
                else:
                    cap_triangles.append([i2, i1, center_idx])  # flip normal

    all_triangles = np.vstack([filtered_triangles, cap_triangles])

    solid_mesh = o3d.geometry.TriangleMesh()
    solid_mesh.vertices = o3d.utility.Vector3dVector(filtered_points)
    solid_mesh.triangles = o3d.utility.Vector3iVector(all_triangles)
    solid_mesh.compute_vertex_normals()
    
    print(f'No of points: {len(np.asarray(solid_mesh.vertices))}')
    
    return solid_mesh

# %%
def plot_all_meshes(
    subject, data_image, foot_length, file_name, volume, 
    point1, point2,
    meshes, list_title):
    
    if file_name == 'File_Path_SFM':
        s = 1
    else:
        s = 0.008
    
    num_meshes = len(meshes)
    # fig = plt.figure(figsize=(15, 5 * num_meshes))
    fig = plt.figure(figsize=(16, 10))
    
    for i, mesh in enumerate(meshes):
        # ax = fig.add_subplot(1, num_meshes, i + 1, projection='3d')
        ax = fig.add_subplot(2, 3, i + 1, projection='3d')
        vertices = np.asarray(mesh.vertices)
        ax.scatter(vertices[:, 0], vertices[:, 1], vertices[:, 2], s=s)
        
        # if list_title[i] in ['Rescaled Mesh']: # 'Remove Small Objects'
        #     ax.scatter(
        #         [point1[0], point2[0]], 
        #         [point1[1], point2[1]], 
        #         [point1[2], point2[2]], 
        #         s=s*10, color='red', label='Longest Distance Points')
            
        #     ax.plot(
        #         [point1[0], point2[0]], 
        #         [point1[1], point2[1]], 
        #         [point1[2], point2[2]], 
        #         color='green', label='Longest Distance Line')
        
        # Set axis labels
        ax.set_xlabel('X axis')
        ax.set_ylabel('Y axis')
        ax.set_zlabel('Z axis')
        
        # Set title
        # ax.set_title(f'3D Mesh Plot {i + 1}')
        # ax.set_title(f'({i+1}) {list_title[i]}\nPoints: {len(vertices)}')
        ax.set_title(f'({i+1}) {list_title[i]}', fontsize=18)
    
    
    # plt.suptitle(f'Subject {subject} - {data_image}\nFoot Length: {foot_length}cm - Points: {len(vertices)}\nVolume: {round(volume, 1)}cm3')
    # plt.suptitle(f'Subject {subject} - {data_image}\nFeet Length: {foot_length}cm\nVolume: {round(volume, 1)}cm3')
    # plt.suptitle(f'Subject {subject} - {data_image}\nFeet Length: {foot_length}cm')
    plt.tight_layout()
    # fig.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9, wspace=0.3)

    folder_save_path = f'/home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_Details/Feet_Preprocessing/{file_name}'
    if not os.path.exists(folder_save_path):
        os.makedirs(folder_save_path)

    save_path = f'{folder_save_path}/subject_{subject}_{data_image}_P.png'
    fig.savefig(save_path, dpi=300)  # Save at high resolution
    plt.close()
    # plt.show()

# %%
def plot_mesh_angles(subject, data_image, foot_length, file_name, 
                     volume,
                     point1, point2, 
                     p_min, p_max,
                     mesh, directions):
    
    if file_name == 'File_Path_SFM':
        s = 1
    else:
        s = 0.008
    
    num_directions = len(directions)

    # fig = plt.figure(figsize=(15, 5 * num_meshes))

    if num_directions == 6:
        fig = plt.figure(figsize=(16, 10))
    else:
        fig = plt.figure(figsize=(10, 10))
    
    for i, direction  in enumerate(directions):
        if num_directions == 6:
            ax = fig.add_subplot(2, 3, i + 1, projection='3d')
        else:
            ax = fig.add_subplot(2, 2, i + 1, projection='3d')
            
        vertices = np.asarray(mesh.vertices)
        ax.scatter(vertices[:, 0], vertices[:, 1], vertices[:, 2], s=s)

        # # Plot foot length line        
        # ax.scatter(
        #     [point1[0], point2[0]], 
        #     [point1[1], point2[1]], 
        #     [point1[2], point2[2]], 
        #     s=s*100, color='green', label='Longest Distance Points')
        
        # ax.plot(
        #     [point1[0], point2[0]], 
        #     [point1[1], point2[1]], 
        #     [point1[2], point2[2]], 
        #     color='green', label='Longest Distance Line')
        
        # ax.scatter(
        #     [p_min[0], p_max[0]], 
        #     [p_min[1], p_max[1]], 
        #     [p_min[2], p_max[2]], 
        #     s=s*100, color='red', label='Longest Distance Points')
        
        # Set axis labels
        ax.set_xlabel('X axis')
        ax.set_ylabel('Y axis')
        ax.set_zlabel('Z axis')
        
        # Set title
        # ax.set_title(f'3D Mesh Plot {i + 1}')
    
        # Interpret direction as [elev, azim]
        if direction is not None:
            elev, azim = direction
            ax.view_init(elev=elev, azim=azim)
            ax.set_title(f'elev:{elev}, azim:{azim}', fontsize=18)
        else:
            ax.set_title('Original View', fontsize=18)

    # plt.suptitle(f'Subject {subject} - {data_image}\nFeet Length: {foot_length}cm - Points: {len(vertices)}\nVolume: {round(volume, 1)}cm3')
    # plt.suptitle(f'Subject {subject} - {data_image}\nFeet Length: {foot_length}cm - Points: {len(vertices)}')
    # plt.suptitle(f'Subject {subject} - {data_image}\nFeet Length: {foot_length}cm')
    # plt.suptitle(f'Subject {subject} - {data_image}\nFeet Length: {foot_length}cm\nVolume: {round(volume, 1)}cm3')
    plt.tight_layout()
    # fig.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9, wspace=0.3)

    folder_save_path = f'/home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_Details/Feet_Orientation/{file_name}'
    if not os.path.exists(folder_save_path):
        os.makedirs(folder_save_path)

    save_path = f'{folder_save_path}/subject_{subject}_{data_image}_O.png'
    fig.savefig(save_path, dpi=300)  # Save at high resolution
    plt.close()

    # plt.show()

# %% [markdown]
# # Main

# %%
df = pd.read_csv(f'/home/weiyanpeh/Git/SFM_Related/CADENCE/results_2_perfect_subjects.csv')
# df = pd.read_csv(f'/home/weiyanpeh/Git/SFM_Related/CADENCE/results_2_all_subjects.csv')
df_subject = pd.read_csv(f'/home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_Details/data_0_summary_grouped.csv')

df
# Out:
#      Subject Image Data        Type  \
# 0          1       1D0L         SFM
# 1          1       1D0L    MVS_mesh
# 2          1       1D0L   MVS_dense
# 3          1       1D0L  MVS_refine
# 4          1       1D0R         SFM
# ..       ...        ...         ...
# 223       46      46D0R  MVS_refine
# 224       74      74D0R         SFM
# 225       74      74D0R    MVS_mesh
# 226       74      74D0R   MVS_dense
# 227       74      74D0R  MVS_refine
#
#                                              File_Path       Volume
# 0    /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_...    49.662720
# 1    /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_...    71.397707
# 2    /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_...    71.156429
# 3    /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_...    71.157388
# 4    /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_...     6.053574
# ..                                                 ...          ...
# 223  /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_...     2.141923
# 224  /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_...  2268.287191
# 225  /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_...   155.341813
# 226  /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_...   154.125191
# 227  /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_...   154.125619
#
# [228 rows x 5 columns]

# %%
# # Testing
# data_type = 'SFM'
# index = 10

# df_temp = df[df['Type'] == data_type].reset_index(drop=True)
# subject = df_temp['Subject'][index]
# data_image = df_temp['Image Data'][index]
# ply_path = df_temp['File_Path'][index]

# file_name = ply_path.split('/')[-1]

# if 'L' in data_image:
#     column = 'Left foot length (cm)'
# else:
#     column = 'Right foot length (cm)'

# list_foot_length = df_subject[df_subject['Subject ID'] == subject][column]
# list_foot_length = list_feet_length.tolist()[0]
# list_foot_length = list_feet_length.replace(', nan', '').replace('nan', '')
# list_feet_length = ast.literal_eval(list_feet_length)
# feet_length = list_feet_length[0] # First

# print('#'*60)
# print(f'Subject {subject} - {data_image} - Feet length {feet_length}cm')
# print(f'{file_name}')
# print(f'{list_feet_length} - {feet_length}')

# #################################################
# # Load PLY file using Open3D
# #################################################
# if data_type != 'File_Path_SFM':
#     mesh = o3d.io.read_triangle_mesh(ply_path) # Read mesh
# else:
#     mesh = o3d.io.read_point_cloud(ply_path) # Read point dense cloud
#     print('Number of Vertices: ', len(mesh.points))

# %%
list_data_type = [
    # 'SFM', 
    # 'MVS_mesh', 
    # 'MVS_dense', 
    'MVS_refine'
    ]

df_results = []

#################################################
# Run data type
#################################################
for data_type in list_data_type:
    
    #################################################
    # Run subjects
    #################################################
    df_temp = df[df['Type'] == data_type].reset_index(drop=True)
    
    for index, row in df_temp.iterrows():
        subject = df_temp['Subject'][index]
        data_image = df_temp['Image Data'][index]
        ply_path = df_temp['File_Path'][index]
        file_name = ply_path.split('/')[-1]

        if 'L' in data_image:
            column = 'Left'
        else:
            column = 'Right'
        
        try:
            list_feet_length = df_subject[df_subject['Subject ID'] == subject][f'{column} foot length (cm)']
            list_feet_length = list_feet_length.tolist()[0]
            list_feet_length = list_feet_length.replace(', nan', '').replace('nan', '')
            list_feet_length = ast.literal_eval(list_feet_length)
            feet_length = list_feet_length[0] # First
            # feet_length = np.mean(feet_length) # Mean
        except:
            feet_length = 25
        
        print('')
        print('#'*60)
        print(f'Subject {subject} - {data_image} - Feet length {feet_length}cm')
        print('#'*60)
        print(f'{file_name}')
        print(f'{list_feet_length} - {feet_length}')
        
        try:
            #################################################
            # Load PLY file using Open3D
            #################################################
            if data_type != 'File_Path_SFM':
                print('\nLoad Mesh')
                mesh = o3d.io.read_triangle_mesh(ply_path) # Read mesh
                print('Number of Vertices: ', len(mesh.vertices))
                
                # Downsample to a target number of triangles
                # print('\nDown sample mesh')
                # target_triangle_count = 50000 # adjust as needed
                # mesh = mesh.simplify_quadric_decimation(target_triangle_count)
                # print('Number of Vertices: ', len(mesh.vertices))

                
            else:
                print('\nLoad Point Dense Cloud')
                mesh = o3d.io.read_point_cloud(ply_path) # Read point dense cloud
                print('Number of Points: ', len(mesh.points))

                # If more than 2000 points, randomly sample
                points = np.asarray(mesh.points)
                if len(points) > 3000:
                    indices = np.random.choice(len(points), size=2000, replace=False)
                    mesh = mesh.select_by_index(indices)

                # mesh = mesh.voxel_down_sample(voxel_size=0.01)
                print('Number of Points (Down Sample): ', len(mesh.points))

                mesh.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30)) # Estimate normals
                mesh.orient_normals_consistent_tangent_plane(100) # Optionally, orient the normals consistently
                
                distances = mesh.compute_nearest_neighbor_distance()
                avg_dist = np.mean(distances)
                radii = [avg_dist, avg_dist * 2]

                radii = [0.05, 0.1, 0.2] # Define radii for the Ball Pivoting algorithm
                mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_ball_pivoting(
                    mesh, 
                    o3d.utility.DoubleVector(radii)
                    ) # Apply the Ball Pivoting algorithm

            #################################################
            # Pipeline to edit mesh
            #################################################
            mesh = remove_isolated_vertices(mesh)
            mesh = shift_to_positive(mesh)
            
            reoriented_mesh = find_floor_plane_and_reorient(copy.deepcopy(mesh))
            reoriented_mesh = shift_to_positive(reoriented_mesh)
            
            cropped_mesh = crop_mesh_z_axis(copy.deepcopy(reoriented_mesh), percentile=17) # 21
            cropped_mesh = shift_to_positive(cropped_mesh)
            
            largest_object_mesh = remove_small_objects(copy.deepcopy(cropped_mesh))
            largest_object_mesh = shift_to_positive(largest_object_mesh)
            
            scaled_mesh, point1, point2, p_min, p_max = scale_longest_xy_axis(copy.deepcopy(largest_object_mesh), feet_length)
            scaled_mesh = shift_to_positive(scaled_mesh)
            
            # rotate_feet_mesh = reorient_feet(copy.deepcopy(scaled_mesh), point1, point2)
            
            cropped_ankle_mesh = crop_mesh_z_axis_ankle(copy.deepcopy(scaled_mesh), z_threshold=12)
            # cropped_ankle_mesh = crop_mesh_z_axis_ankle(scaled_mesh, z_threshold=12)
            # cropped_ankle_mesh = copy.deepcopy(scaled_mesh)
            cropped_ankle_mesh = shift_to_positive(cropped_ankle_mesh)
            
            # solid_mesh = solidify_mesh_with_fans(copy.deepcopy(cropped_ankle_mesh))


            #################################################
            # Clean output
            #################################################
            final_mesh = copy.deepcopy(cropped_ankle_mesh)
            final_mesh = shift_to_positive(final_mesh)
            print('\nCleaning output')
            final_mesh.remove_duplicated_vertices()
            final_mesh.remove_degenerate_triangles()
            final_mesh.remove_unreferenced_vertices()
            final_mesh.remove_non_manifold_edges()
            final_mesh_vertices = np.asarray(final_mesh.vertices)
            
            # Check if the mesh is still valid
            if not mesh.is_edge_manifold():
                print("Warning: Mesh is not edge-manifold.")
            if not mesh.is_vertex_manifold():
                print("Warning: Mesh is not vertex-manifold.")

            print(f'No of points: {len(np.asarray(final_mesh.vertices))}')


            #################################################
            # Saving results
            #################################################
            print('\nSaving Final Mesh')
            path_save = f'/home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_Frames_edit/{subject}/{data_image}'
            if not os.path.exists(path_save):
                os.makedirs(path_save)
            o3d.io.write_triangle_mesh(f'{path_save}/postprocessed_{file_name}', final_mesh)

            # Visualize the PLY file
            # o3d.visualization.draw_geometries([reoriented_mesh])
            # plot_mesh(reoriented_mesh)

            #################################################
            # Saving results
            #################################################
            print(f'\nCalculating Volume')
            try:
                volume = calculate_volume_file(
                    file_path = f'{path_save}', 
                    file_name = f'postprocessed_{file_name}'
                    )
                error = ''
            except Exception as error:
                print(error)
                volume = 0
            
            print(f'{file_name} - Volume: {round(volume, 3)} cm3')

            #################################################
            # Plot processed meshes
            #################################################            
            plot_all_meshes(
                subject, data_image, feet_length, file_name.replace('.ply', ''), volume,
                point1, point2,
                [
                    mesh, reoriented_mesh, cropped_mesh, 
                    largest_object_mesh, scaled_mesh, cropped_ankle_mesh
                ],
                [
                    'Initial', 'Reorientate Mesh to Align Floor', 'Crop Floor',
                    'Remove Other Objects', 'Rescaling', 'Crop Ankle'
                ]
            )
            
            #################################################
            # Plot different orientation of final meshes
            #################################################
            # front, side, top, diagonal
            # directions = [np.array([0, 0]), np.array([0, 90]), np.array([90, 0]), np.array([45, 45])]
                
            # Define 9 diverse viewing directions
            # directions = [
            #     np.array([0, 0]), np.array([0, 90]), np.array([0, 180]), np.array([0, 270]),
            #     np.array([90, 0]), np.array([90, 90]), np.array([90, 180]), np.array([90, 270]),
            #     np.array([45, 45]), np.array([135, 135]), np.array([225, 225]), np.array([315, 315])
            # ]

            # 6 views
            directions = [None, np.array([0, 0]), np.array([0, 90]), np.array([0, 180]), np.array([90, 0]), np.array([45, 45])]

            plot_mesh_angles(
                subject, data_image, feet_length, file_name.replace('.ply', ''), volume,
                point1, point2, p_min, p_max,
                final_mesh,
                directions
            )
            
            plt.show()
            
            results = [subject, data_image, ply_path, file_name, column, feet_length, 
                       len(mesh.vertices),
                       len(reoriented_mesh.vertices),
                       len(cropped_mesh.vertices),
                       len(largest_object_mesh.vertices),
                       len(scaled_mesh.vertices),
                       len(cropped_ankle_mesh.vertices),
                       len(final_mesh.vertices),
                       volume,
                       ''
                       ]
            df_results.append(results)

        except Exception as error:
            print('ERROR')
            print(error)
            
            results = [subject, data_image, ply_path, file_name, column, feet_length, 
                       0,
                       0,
                       0,
                       0,
                       0,
                       0,
                       0,
                       0,
                       error
                       ]
            df_results.append(results)
            
columns = ['subject', 'data_image', 'ply_path', 'file_name', 'direction', 'feet_length',
           'points_mesh', 'points_reoriented', 'points_cropped', 'points_remove_large', 'points_scaled',
           'points_cropped_ankle', 'points_final', 'volume', 'error'
           ]
df_results = pd.DataFrame(df_results, columns=columns)
# df_results.to_csv(f'/home/weiyanpeh/Git/SFM_Related/CADENCE/results_3_final_volume.csv', index=False)
df_results.to_csv(f'/home/weiyanpeh/Git/SFM_Related/CADENCE/results_3_final_volume_perfect.csv', index=False)
# Out:
# ############################################################
# Subject 1 - 1D0L - Feet length 24.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [24.0] - 24.0
#
# Load Mesh
# Number of Vertices:  39520
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 39520
#
# Locating floor plane and reorientate to x-y plane
# No of points: 39520
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 19950
#
# Perform mesh clustering to remove small objects
# Range: [ 7.81061873 10.8631419   1.98959883]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({0: 13383, 1: 6495, -1: 45, 2: 27})
# 3 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 13383===============================>] 97%
#
# Scaling longest x-y axis based on foot length: 24.0cm
# Scaling Factor: 5.6 - Estimated Distance: 4.3 - Target Length: 24.0
# No of points: 13383
#
# Cropping mesh from the top
# Max value: 8.838932143042793
# No of points: 13383
#
# Cleaning output
# No of points: 13383
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1047.276 cm3
#
# ############################################################
# Subject 1 - 1D0R - Feet length 25.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.0] - 25.0
#
# Load Mesh
# Number of Vertices:  57078
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 57078
#
# Locating floor plane and reorientate to x-y plane
# No of points: 57078
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 21966
#
# Perform mesh clustering to remove small objects
# Range: [1.55184194 1.57791788 0.66060918]
# eps: 0.1
# min_points 10
# Precompute neighbors.[================>           Counter:    ] 37%
# Counter({0: 21714, 1: 236, 2: 16})
# 3 cluster found!
# Precompute neighbors.[========================================] 100%
# Clustering[========================================] 100%
# No of points: 21714
#
# Scaling longest x-y axis based on foot length: 25.0cm
# Scaling Factor: 24.2 - Estimated Distance: 1.0 - Target Length: 25.0
# No of points: 21714
#
# Cropping mesh from the top
# Max value: 15.966837097741395
# No of points: 19410
#
# Cleaning output
# No of points: 19409
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1622.199 cm3
#
# ############################################################
# Subject 4 - 4D0L - Feet length 25.1cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.1, 25.5, 25.5] - 25.1
#
# Load Mesh
# Number of Vertices:  50614
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 50614
#
# Locating floor plane and reorientate to x-y plane
# No of points: 50614
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 26572
#
# Perform mesh clustering to remove small objects
# Range: [1.76438111 1.1407918  1.15066671]
# eps: 0.1
# min_points 10
# Precompute neighbors.[========Counter:==============>         ] 75%
# Counter({0: 26572})
# Only 1 cluster found!
# No of points: 26572
# Precompute neighbors.[========================================] 100%
# Clustering[========================================] 100%
#
# Scaling longest x-y axis based on foot length: 25.1cm
# Scaling Factor: 14.2 - Estimated Distance: 1.8 - Target Length: 25.1
# No of points: 26572
#
# Cropping mesh from the top
# Max value: 16.369328749206883
# No of points: 22825
#
# Cleaning output
# No of points: 22825
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1439.733 cm3
#
# ############################################################
# Subject 4 - 4D0R - Feet length 24.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [24.5, 25.5, 25.0] - 24.5
#
# Load Mesh
# [Open3D WARNING] Read PLY failed: unable to open file: /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_Frames_output/mvg_mvs_100_5/4/4D0R/mvs/scene_dense_mesh_refine.ply
# Number of Vertices:  0
#
# Removing isolated vertices using DBSCAN clustering
# [Open3D WARNING] [KDTreeFlann::SetRawData] Failed due to no data.
# ERROR
# attempt to get argmax of an empty sequence
#
# ############################################################
# Subject 4 - 4D1L - Feet length 25.1cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.1, 25.5, 25.5] - 25.1
#
# Load Mesh
# Number of Vertices:  12655
#
# Removing isolated vertices using DBSCAN clustering
# RPly: Unable to open file
# Remaining vertices: 12655
#
# Locating floor plane and reorientate to x-y plane
# No of points: 12655
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 10303
#
# Perform mesh clustering to remove small objects
# Range: [ 7.06030582 10.28057275  3.3143401 ]
# eps: 0.1
# min_points 10
# Counter:
# Counter({-1: 8360, 23: 151, 10: 106, 46: 82, 36: 73, 41: 72, 25: 58, 39: 46, 53: 44, 40: 44, 6: 43, 27: 42, 18: 39, 9: 38, 49: 32, 1: 30, 38: 30, 31: 27, 0: 26, 3: 26, 34: 26, 56: 26, 4: 25, 48: 24, 58: 24, 7: 23, 30: 23, 59: 23, 22: 22, 42: 22, 21: 20, 35: 20, 52: 19, 12: 18, 24: 17, 66: 17, 50: 17, 29: 16, 13: 16, 17: 16, 51: 16, 43: 16, 2: 15, 37: 15, 44: 15, 26: 15, 54: 15, 45: 14, 73: 14, 33: 13, 64: 13, 76: 13, 20: 12, 19: 11, 78: 11, 82: 11, 11: 10, 61: 10, 75: 10, 5: 10, 28: 10, 69: 10, 8: 10, 71: 10, 15: 10, 14: 10, 84: 10, 81: 10, 77: 10, 63: 10, 79: 10, 65: 10, 47: 10, 80: 10, 86: 10, 70: 10, 55: 10, 85: 10, 60: 10, 83: 9, 32: 9, 57: 9, 62: 8, 67: 8, 68: 8, 72: 8, 74: 7, 16: 5})Precompute neighbors.[=>                                      ] 2%
# 87 cluster found!
# Precompute neighbors.[========================================] 100%
# Too many points are removed! Undo step             ] 17%
# New - No of points: 151
# Old - No of points: 10303
#
# Scaling longest x-y axis based on foot length: 25.1cm
# Scaling Factor: 2.4 - Estimated Distance: 10.3 - Target Length: 25.1
# No of points: 10303
#
# Cropping mesh from the top
# Max value: 8.09195543628563
# No of points: 10303
#
# Cleaning output
# No of points: 10302
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1382.669 cm3
#
# ############################################################
# Subject 4 - 4D1R - Feet length 24.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [24.5, 25.5, 25.0] - 24.5
#
# Load Mesh
# Number of Vertices:  30313
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 30313
#
# Locating floor plane and reorientate to x-y plane
# No of points: 30313
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 20220
#
# Perform mesh clustering to remove small objects
# Range: [2.35020116 3.75496408 1.39122442]
# eps: 0.1
# min_points 10
# Precompute neighbors.[========================================] 100%  ] 5%
# Clustering[========================================] 100%
#
# Counter({0: 17950, 1: 2260, 2: 10})
# 3 cluster found!
# No of points: 17950
#
# Scaling longest x-y axis based on foot length: 24.5cm
# Scaling Factor: 10.9 - Estimated Distance: 2.3 - Target Length: 24.5
# No of points: 17950
#
# Cropping mesh from the top
# Max value: 15.039640494011376
# No of points: 16482
#
# Cleaning output
# No of points: 16482
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1339.862 cm3
#
# ############################################################
# Subject 4 - 4D2L - Feet length 25.1cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.1, 25.5, 25.5] - 25.1
#
# Load Mesh
# Number of Vertices:  35612
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 15957
#
# Locating floor plane and reorientate to x-y plane
# No of points: 15957
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 8940
#
# Perform mesh clustering to remove small objects
# Range: [1.87407602 3.68086042 1.58401254]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({0: 8497, 1: 429, -1: 14})
# 2 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 8497================================>] 97%
#
# Scaling longest x-y axis based on foot length: 25.1cm
# Scaling Factor: 13.4 - Estimated Distance: 1.9 - Target Length: 25.1
# No of points: 8497
#
# Cropping mesh from the top
# Max value: 21.215102434828115
# No of points: 5948
#
# Cleaning output
# No of points: 5948
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 2074.216 cm3
#
# ############################################################
# Subject 4 - 4D2R - Feet length 24.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [24.5, 25.5, 25.0] - 24.5
#
# Load Mesh
# Number of Vertices:  40759
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 32709
#
# Locating floor plane and reorientate to x-y plane
# No of points: 32709
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 20708
#
# Perform mesh clustering to remove small objects
# Range: [5.21133952 4.87981612 2.35554565]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({1: 17958, 0: 2631, 2: 70, -1: 49})
# Precompute neighbors.[================>           3 cluster found!%
# Precompute neighbors.[========================================] 100%
# No of points: 17958===============================>] 97%
#
# Scaling longest x-y axis based on foot length: 24.5cm
# Scaling Factor: 8.2 - Estimated Distance: 3.0 - Target Length: 24.5
# No of points: 17958
#
# Cropping mesh from the top
# Max value: 16.48514633613687
# No of points: 15312
#
# Cleaning output
# No of points: 15312
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1701.845 cm3
#
# ############################################################
# Subject 6 - 6D0L - Feet length 24.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [24.5, 25.0, 25.0] - 24.5
#
# Load Mesh
# Number of Vertices:  19099
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 19099
#
# Locating floor plane and reorientate to x-y plane
# No of points: 19099
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 10568
#
# Perform mesh clustering to remove small objects
# Range: [ 9.61670752 18.63776563  5.03946683]
# eps: 0.1
# min_points 10
# Counter:
# Counter({-1: 7783, 17: 282, 6: 110, 47: 106, 39: 70, 49: 65, 37: 51, 14: 44, 35: 44, 33: 44, 2: 37, 60: 37, 57: 34, 18: 32, 5: 31, 24: 30, 12: 29, 78: 28, 56: 28, 42: 27, 61: 27, 20: 27, 31: 26, 25: 26, 50: 26, 53: 26, 79: 26, 36: 25, 82: 25, 9: 24, 45: 24, 59: 23, 84: 23, 26: 22, 34: 22, 63: 22, 58: 22, 21: 22, 44: 22, 3: 21, 15: 21, 62: 21, 66: 21, 112: 21, 86: 21, 48: 21, 83: 21, 7: 20, 32: 20, 89: 20, 4: 19, 65: 19, 30: 18, 11: 18, 19: 18, 52: 18, 64: 18, 23: 17, 99: 17, 40: 17, 73: 17, 0: 16, 77: 16, 43: 16, 46: 16, 74: 15, 101: 15, 71: 15, 116: 14, 10: 14, 13: 14, 28: 14, 95: 14, 22: 14, 102: 14, 108: 14, 1: 13, 88: 13, 55: 13, 16: 13, 87: 13, 100: 13, 69: 13, 80: 13, 96: 12, 29: 12, 38: 12, 75: 12, 51: 12, 72: 12, 85: 12, 110: 12, 41: 11, 68: 11, 76: 11, 54: 11, 104: 11, 90: 10, 93: 10, 8: 10, 111: 10, 94: 10, 67: 10, 91: 10, 106: 10, 27: 10, 98: 10, 126: 10, 125: 10, 103: 10, 115: 10, 118: 10, 120: 10, 105: 10, 123: 10, 117: 10, 127: 10, 107: 10, 81: 10, 122: 10, 92: 9, 97: 9, 70: 8, 109: 7, 113: 7, 124: 7, 114: 7, 119: 6, 121: 6})
# 128 cluster found!
# Precompute neighbors.[========================================] 100%
# Too many points are removed! Undo step             ] 25%
# New - No of points: 282
# Old - No of points: 10568
#
# Scaling longest x-y axis based on foot length: 24.5cm
# Scaling Factor: 1.3 - Estimated Distance: 18.6 - Target Length: 24.5
# No of points: 10568
#
# Cropping mesh from the top
# Max value: 6.624556820196383
# No of points: 10568
#
# Cleaning output
# No of points: 10568
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 566.988 cm3
#
# ############################################################
# Subject 6 - 6D0R - Feet length 25.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.0, 24.5, 25.0] - 25.0
#
# Load Mesh
# Number of Vertices:  4527
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 4527
#
# Locating floor plane and reorientate to x-y plane
# No of points: 4527
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 4489
#
# Perform mesh clustering to remove small objects
# Range: [2.34421519 3.5121071  1.79627201]
# eps: 0.1
# min_points 10
# Counter:
# Counter({0: 3776, -1: 679, 1: 34})
# Precompute neighbors.[========================================] 100%
# 2 cluster found!============================>      ] 82%
# No of points: 3776
#
# Scaling longest x-y axis based on foot length: 25.0cm
# Scaling Factor: 7.1 - Estimated Distance: 3.5 - Target Length: 25.0
# No of points: 3776
#
# Cropping mesh from the top
# Max value: 10.643531150472832
# No of points: 3776
#
# Cleaning output
# No of points: 3776
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1481.29 cm3
#
# ############################################################
# Subject 6 - 6D1L - Feet length 24.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [24.5, 25.0, 25.0] - 24.5
#
# Load Mesh
# Number of Vertices:  38411
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 38411
#
# Locating floor plane and reorientate to x-y plane
# No of points: 38411
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 22112
#
# Perform mesh clustering to remove small objects
# Range: [2.57718083 1.20970376 1.27342364]
# eps: 0.1
# min_points 10
# Precompute neighbors.[========================================] 100%
# Clustering[========================================] 100%
# Counter:
# Counter({0: 22112})
# Only 1 cluster found!
# No of points: 22112
#
# Scaling longest x-y axis based on foot length: 24.5cm
# Scaling Factor: 9.5 - Estimated Distance: 2.6 - Target Length: 24.5
# No of points: 22112
#
# Cropping mesh from the top
# Max value: 12.105816897472446
# No of points: 22090
#
# Cleaning output
# No of points: 22090
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1259.84 cm3
#
# ############################################################
# Subject 6 - 6D1R - Feet length 25.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.0, 24.5, 25.0] - 25.0
#
# Load Mesh
# Number of Vertices:  31756
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 29805
#
# Locating floor plane and reorientate to x-y plane
# No of points: 29805
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 17955
#
# Perform mesh clustering to remove small objects
# Range: [4.3001893  1.56061394 3.60058699]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({0: 17817, 1: 70, -1: 68})
# 2 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 17817===============================>] 97%
#
# Scaling longest x-y axis based on foot length: 25.0cm
# Scaling Factor: 6.3 - Estimated Distance: 3.9 - Target Length: 25.0
# No of points: 17817
#
# Cropping mesh from the top
# Max value: 22.8558426090425
# No of points: 11770
#
# Cleaning output
# No of points: 11770
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1226.914 cm3
#
# ############################################################
# Subject 6 - 6D2L - Feet length 24.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [24.5, 25.0, 25.0] - 24.5
#
# Load Mesh
# Number of Vertices:  23467
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 23467
#
# Locating floor plane and reorientate to x-y plane
# No of points: 23467
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 12134
#
# Perform mesh clustering to remove small objects
# Range: [ 8.54536777 12.6476844   5.98166911]
# eps: 0.1
# min_points 10
# Counter:
# Counter({-1: 9742, 6: 95, 2: 89, 70: 75, 21: 67, 46: 51, 1: 45, 43: 35, 69: 33, 0: 32, 63: 31, 24: 31, 12: 29, 31: 29, 13: 27, 81: 27, 19: 25, 48: 25, 58: 24, 49: 24, 64: 24, 53: 23, 74: 23, 39: 23, 51: 23, 68: 23, 71: 23, 45: 22, 11: 22, 80: 22, 9: 21, 17: 21, 67: 21, 47: 21, 25: 20, 34: 19, 10: 19, 16: 19, 62: 19, 22: 19, 111: 18, 97: 18, 35: 18, 28: 18, 78: 18, 37: 17, 75: 17, 15: 17, 60: 17, 33: 16, 8: 16, 93: 16, 113: 16, 20: 16, 29: 16, 30: 16, 66: 16, 61: 16, 65: 16, 96: 15, 52: 15, 73: 15, 104: 15, 26: 15, 87: 15, 56: 15, 79: 15, 5: 14, 88: 14, 3: 14, 124: 14, 18: 14, 108: 14, 77: 14, 41: 14, 36: 14, 40: 14, 55: 14, 90: 14, 57: 13, 38: 13, 102: 13, 106: 13, 91: 13, 107: 13, 131: 13, 85: 13, 50: 12, 32: 12, 42: 12, 84: 12, 89: 11, 86: 11, 125: 11, 7: 10, 103: 10, 23: 10, 4: 10, 127: 10, 126: 10, 105: 10, 129: 10, 94: 10, 92: 10, 14: 10, 95: 10, 27: 10, 116: 10, 120: 10, 98: 10, 118: 10, 122: 10, 100: 10, 121: 10, 101: 10, 54: 10, 115: 10, 112: 10, 72: 10, 109: 10, 110: 10, 128: 10, 76: 10, 130: 10, 114: 10, 82: 10, 119: 10, 123: 10, 44: 9, 99: 9, 83: 8, 117: 7, 59: 7})
# 132 cluster found!
# Precompute neighbors.[========================================] 100%
# Too many points are removed! Undo step             ] 17%
# New - No of points: 95
# Old - No of points: 12134
#
# Scaling longest x-y axis based on foot length: 24.5cm
# Scaling Factor: 1.9 - Estimated Distance: 12.6 - Target Length: 24.5
# No of points: 12134
#
# Cropping mesh from the top
# Max value: 11.587171886945713
# No of points: 12134
#
# Cleaning output
# No of points: 12132
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1181.841 cm3
#
# ############################################################
# Subject 6 - 6D2R - Feet length 25.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.0, 24.5, 25.0] - 25.0
#
# Load Mesh
# Number of Vertices:  16790
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 16382
#
# Locating floor plane and reorientate to x-y plane
# No of points: 16382
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 15374
#
# Perform mesh clustering to remove small objects
# Range: [13.07928187 41.49900213  9.46238098]
# eps: 0.1
# min_points 10
# Counter:
# Counter({-1: 15374})
# Only 1 cluster found!
# No of points: 15374
# Precompute neighbors.[========================================] 100%
#
# Scaling longest x-y axis based on foot length: 25.0cm
# Scaling Factor: 0.6 - Estimated Distance: 41.5 - Target Length: 25.0
# No of points: 15374
#
# Cropping mesh from the top
# Max value: 5.700366571507901
# No of points: 15374
#
# Cleaning output
# No of points: 15374
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 381.708 cm3
#
# ############################################################
# Subject 7 - 7D0L - Feet length 25.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.5, 26.0] - 25.5
#
# Load Mesh
# Number of Vertices:  21402
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 18836
#
# Locating floor plane and reorientate to x-y plane
# No of points: 18836
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 10203
#
# Perform mesh clustering to remove small objects
# Range: [19.12489098 15.70380843  9.86776983]
# eps: 0.1
# min_points 10
# Counter:
# Counter({-1: 10203})
# Only 1 cluster found!
# No of points: 10203
# Precompute neighbors.[========================================] 100%
#
# Scaling longest x-y axis based on foot length: 25.5cm
# Scaling Factor: 1.3 - Estimated Distance: 19.1 - Target Length: 25.5
# No of points: 10203
#
# Cropping mesh from the top
# Max value: 13.157101440114248
# No of points: 10074
#
# Cleaning output
# No of points: 10074
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 2369.554 cm3
#
# ############################################################
# Subject 7 - 7D0R - Feet length 25.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.5, 26.0] - 25.5
#
# Load Mesh
# Number of Vertices:  18448
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 16812
#
# Locating floor plane and reorientate to x-y plane
# No of points: 16812
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 10375
#
# Perform mesh clustering to remove small objects
# Range: [21.90107817 40.11833558 24.81213785]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({-1: 10375})
# Only 1 cluster found!
# No of points: 10375
# Precompute neighbors.[========================================] 100%
#
# Scaling longest x-y axis based on foot length: 25.5cm
# Scaling Factor: 0.6 - Estimated Distance: 40.1 - Target Length: 25.5
# No of points: 10375
#
# Cropping mesh from the top
# Max value: 15.771080875603745
# No of points: 8906
#
# Cleaning output
# Warning: Mesh is not vertex-manifold.
# No of points: 8905
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1365.91 cm3
#
# ############################################################
# Subject 7 - 7D1L - Feet length 25.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.5, 26.0] - 25.5
#
# Load Mesh
# Number of Vertices:  8299
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 8299
#
# Locating floor plane and reorientate to x-y plane
# No of points: 8299
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 7155
#
# Perform mesh clustering to remove small objects
# Range: [ 7.58646615 13.44988604  7.21492677]
# eps: 0.1
# min_points 10
# Counter:
# Counter({-1: 7155})
# Only 1 cluster found!
# No of points: 7155
# Precompute neighbors.[========================================] 100%
#
# Scaling longest x-y axis based on foot length: 25.5cm
# Scaling Factor: 1.9 - Estimated Distance: 13.4 - Target Length: 25.5
# No of points: 7155
#
# Cropping mesh from the top
# Max value: 13.678973349533182
# No of points: 6842
#
# Cleaning output
# No of points: 6839
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1922.746 cm3
#
# ############################################################
# Subject 7 - 7D1R - Feet length 25.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.5, 26.0] - 25.5
#
# Load Mesh
# Number of Vertices:  31300
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 24590
#
# Locating floor plane and reorientate to x-y plane
# No of points: 24590
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 11856
#
# Perform mesh clustering to remove small objects
# Range: [22.83890536 28.28721629  9.73109961]
# eps: 0.1
# min_points 10
# Counter:
# Counter({-1: 11856})
# Only 1 cluster found!
# No of points: 11856
# Precompute neighbors.[========================================] 100%
#
# Scaling longest x-y axis based on foot length: 25.5cm
# Scaling Factor: 0.9 - Estimated Distance: 28.3 - Target Length: 25.5
# No of points: 11856
#
# Cropping mesh from the top
# Max value: 8.772267924479278
# No of points: 11856
#
# Cleaning output
# No of points: 11852
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1738.174 cm3
#
# ############################################################
# Subject 12 - 12D0L - Feet length 23.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [23.5] - 23.5
#
# Load Mesh
# Number of Vertices:  25775
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 25775
#
# Locating floor plane and reorientate to x-y plane
# No of points: 25775
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 14613
#
# Perform mesh clustering to remove small objects
# Range: [5.81387608 8.98321906 3.56821392]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({0: 10991, -1: 2704, 1: 192, 2: 164, 10: 112, 7: 36, 8: 28, 24: 28, 15: 26, 5: 26, 14: 26, 4: 20, 12: 19, 19: 19, 9: 19, 22: 19, 3: 18, 18: 16, 20: 16, 13: 15, 11: 14, 25: 14, 21: 13, 23: 12, 29: 10, 6: 10, 16: 10, 17: 10, 27: 10, 28: 10, 26: 6})
# 30 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 10991========================>       ] 80%
#
# Scaling longest x-y axis based on foot length: 23.5cm
# Scaling Factor: 5.7 - Estimated Distance: 4.1 - Target Length: 23.5
# No of points: 10991
#
# Cropping mesh from the top
# Max value: 19.479513623650494
# No of points: 8889
#
# Cleaning output
# No of points: 8889
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1510.027 cm3
#
# ############################################################
# Subject 12 - 12D0R - Feet length 23.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [23.0] - 23.0
#
# Load Mesh
# Number of Vertices:  10583
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 10583
#
# Locating floor plane and reorientate to x-y plane
# No of points: 10583
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 4738
#
# Perform mesh clustering to remove small objects
# Range: [ 6.39078751 10.86712493  3.47057865]
# eps: 0.1
# min_points 10
# Counter:
# Counter({-1: 4718, 0: 10, 1: 10})
# 2 cluster found!
# Precompute neighbors.[========================================] 100%
# Too many points are removed! Undo step
# New - No of points: 10
# Old - No of points: 4738
#
# Scaling longest x-y axis based on foot length: 23.0cm
# Scaling Factor: 2.1 - Estimated Distance: 10.9 - Target Length: 23.0
# No of points: 4738
#
# Cropping mesh from the top
# Max value: 7.345393507242275
# No of points: 4738
#
# Cleaning output
# No of points: 4733
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 723.922 cm3
#
# ############################################################
# Subject 15 - 15D0L - Feet length 23.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [23.5, 23.5, 23.5] - 23.5
#
# Load Mesh
# Number of Vertices:  27381
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 27381
#
# Locating floor plane and reorientate to x-y plane
# No of points: 27381
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 16612
#
# Perform mesh clustering to remove small objects
# Range: [10.3319869  18.36929762  5.29038555]
# eps: 0.1
# min_points 10
# Precompute neighbors.[========================================] 100%
# Counter:ng[======================>                 ] 55%
# Counter({-1: 7443, 23: 581, 14: 576, 5: 321, 6: 297, 100: 249, 20: 164, 40: 161, 91: 160, 61: 146, 90: 129, 24: 124, 92: 123, 11: 113, 15: 111, 56: 105, 43: 104, 22: 100, 48: 98, 116: 95, 124: 94, 9: 90, 148: 87, 89: 83, 16: 79, 64: 73, 125: 67, 46: 66, 34: 65, 127: 65, 2: 64, 111: 64, 45: 59, 81: 59, 13: 58, 21: 57, 138: 57, 156: 57, 29: 56, 97: 56, 28: 55, 177: 55, 126: 52, 87: 52, 72: 50, 12: 49, 104: 49, 27: 49, 39: 49, 117: 46, 4: 45, 8: 45, 118: 45, 26: 43, 131: 43, 49: 43, 76: 43, 36: 42, 99: 42, 0: 41, 10: 41, 88: 41, 7: 40, 37: 40, 60: 40, 25: 39, 19: 38, 94: 38, 96: 38, 158: 36, 143: 36, 82: 35, 38: 34, 107: 33, 157: 33, 52: 32, 51: 32, 150: 32, 78: 31, 102: 30, 86: 30, 120: 30, 59: 29, 57: 29, 144: 29, 141: 29, 149: 29, 98: 28, 115: 28, 103: 28, 112: 28, 110: 27, 65: 26, 139: 26, 41: 26, 42: 26, 135: 26, 142: 25, 35: 24, 63: 24, 44: 24, 55: 24, 174: 24, 146: 24, 50: 23, 171: 23, 129: 23, 160: 23, 134: 22, 109: 22, 108: 22, 71: 21, 54: 20, 80: 20, 184: 20, 152: 20, 176: 20, 3: 19, 128: 19, 83: 19, 122: 19, 130: 19, 137: 19, 145: 19, 182: 19, 47: 18, 70: 18, 119: 18, 178: 18, 136: 18, 62: 17, 192: 17, 155: 17, 140: 17, 162: 17, 75: 16, 17: 16, 32: 16, 33: 16, 159: 16, 58: 16, 73: 16, 216: 16, 95: 16, 114: 16, 206: 16, 198: 15, 18: 15, 133: 15, 180: 15, 30: 15, 31: 15, 123: 15, 161: 15, 191: 15, 194: 15, 84: 15, 101: 15, 121: 15, 203: 15, 69: 14, 77: 14, 85: 14, 168: 14, 196: 14, 170: 14, 169: 14, 1: 13, 230: 13, 164: 13, 167: 13, 202: 13, 217: 13, 147: 13, 181: 13, 172: 13, 105: 12, 188: 12, 93: 12, 166: 11, 187: 11, 189: 11, 113: 11, 151: 11, 183: 11, 175: 11, 53: 10, 214: 10, 223: 10, 190: 10, 68: 10, 195: 10, 229: 10, 212: 10, 197: 10, 218: 10, 219: 10, 221: 10, 106: 10, 201: 10, 132: 10, 226: 10, 153: 10, 211: 10, 154: 10, 210: 10, 234: 10, 213: 10, 225: 10, 173: 10, 67: 9, 200: 9, 222: 9, 231: 9, 227: 9, 209: 9, 163: 8, 215: 8, 185: 8, 224: 8, 199: 8, 205: 8, 179: 8, 208: 8, 165: 8, 79: 7, 66: 7, 74: 7, 204: 7, 228: 7, 186: 7, 232: 7, 207: 6, 233: 6, 220: 5, 193: 4})
# 235 cluster found!
# Too many points are removed! Undo step
# New - No of points: 581
# Old - No of points: 16612
#
# Scaling longest x-y axis based on foot length: 23.5cm
# Scaling Factor: 1.3 - Estimated Distance: 18.4 - Target Length: 23.5
# No of points: 16612
#
# Cropping mesh from the top
# Max value: 6.768035617875977
# No of points: 16612
#
# Cleaning output
# No of points: 16606
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 466.975 cm3
#
# ############################################################
# Subject 15 - 15D0R - Feet length 23.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [23.5, 23.5, 23.5] - 23.5
#
# Load Mesh
# Number of Vertices:  6044
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 6039
#
# Locating floor plane and reorientate to x-y plane
# No of points: 6039
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 6010
#
# Perform mesh clustering to remove small objects
# Range: [2.17431073 3.6270613  0.97139283]
# eps: 0.1
# min_points 10
# Counter:
# Counter({0: 5350, -1: 650, 1: 10})
# 2 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 5350============================>    ] 87%
#
# Scaling longest x-y axis based on foot length: 23.5cm
# Scaling Factor: 6.5 - Estimated Distance: 3.6 - Target Length: 23.5
# No of points: 5350
#
# Cropping mesh from the top
# Max value: 5.91198077897581
# No of points: 5350
#
# Cleaning output
# No of points: 5350
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 785.86 cm3
#
# ############################################################
# Subject 15 - 15D1L - Feet length 23.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [23.5, 23.5, 23.5] - 23.5
#
# Load Mesh
# Number of Vertices:  17856
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 17856
#
# Locating floor plane and reorientate to x-y plane
# No of points: 17856
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 10373
#
# Perform mesh clustering to remove small objects
# Range: [1.32807769 2.58973749 1.65779216]
# eps: 0.1
# min_points 10
# Precompute neighbors.[========================================] 100%
# Counter:ng[=======================================>] 97%
# Counter({0: 10369, -1: 4})
# Only 1 cluster found!
# No of points: 10373
#
# Scaling longest x-y axis based on foot length: 23.5cm
# Scaling Factor: 9.1 - Estimated Distance: 2.6 - Target Length: 23.5
# No of points: 10373
#
# Cropping mesh from the top
# Max value: 15.04326822309593
# No of points: 9584
#
# Cleaning output
# No of points: 9584
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1215.538 cm3
#
# ############################################################
# Subject 15 - 15D1R - Feet length 23.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [23.5, 23.5, 23.5] - 23.5
#
# Load Mesh
# Number of Vertices:  23562
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 23562
#
# Locating floor plane and reorientate to x-y plane
# No of points: 23562
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 12481
#
# Perform mesh clustering to remove small objects
# Range: [ 9.98959467 13.96963102  5.61913273]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({-1: 4474, 0: 2829, 4: 1297, 3: 971, 6: 419, 21: 229, 9: 178, 5: 111, 1: 103, 10: 103, 13: 101, 22: 98, 8: 88, 17: 81, 20: 80, 18: 75, 19: 67, 11: 66, 26: 58, 33: 58, 24: 57, 16: 57, 31: 52, 7: 47, 25: 45, 15: 44, 28: 39, 32: 39, 43: 33, 2: 30, 46: 30, 30: 30, 44: 29, 39: 28, 23: 27, 12: 24, 38: 23, 37: 21, 53: 21, 35: 19, 14: 18, 50: 18, 34: 17, 52: 17, 36: 17, 51: 16, 27: 14, 42: 14, 48: 13, 55: 12, 45: 11, 29: 10, 47: 10, 63: 10, 62: 10, 49: 10, 57: 10, 61: 10, 59: 9, 58: 9, 41: 9, 60: 9, 56: 8, 54: 7, 64: 7, 40: 5})
# Precompute neighbors.[========================================] 100%
# 65 cluster found!===================>              ] 62%
# No of points: 2829
#
# Scaling longest x-y axis based on foot length: 23.5cm
# Scaling Factor: 6.6 - Estimated Distance: 3.5 - Target Length: 23.5
# No of points: 2829
#
# Cropping mesh from the top
# Max value: 7.766896024068706
# No of points: 2829
#
# Cleaning output
# No of points: 2829
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1262.44 cm3
#
# ############################################################
# Subject 15 - 15D2L - Feet length 23.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [23.5, 23.5, 23.5] - 23.5
#
# Load Mesh
# Number of Vertices:  7649
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 7649
#
# Locating floor plane and reorientate to x-y plane
# No of points: 7649
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 5272
#
# Perform mesh clustering to remove small objects
# Range: [2.03517301 3.26999721 1.40062094]
# eps: 0.1
# min_points 10
# Precompute neighbors.[========================================] 100%
# Counter:ng[=====================================>  ] 92%
# Counter({0: 4946, -1: 305, 1: 21})
# 2 cluster found!
# No of points: 4946
#
# Scaling longest x-y axis based on foot length: 23.5cm
# Scaling Factor: 7.2 - Estimated Distance: 3.3 - Target Length: 23.5
# No of points: 4946
#
# Cropping mesh from the top
# Max value: 10.065633098533873
# No of points: 4946
#
# Cleaning output
# No of points: 4946
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 700.52 cm3
#
# ############################################################
# Subject 15 - 15D2R - Feet length 23.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [23.5, 23.5, 23.5] - 23.5
#
# Load Mesh
# Number of Vertices:  24304
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 24304
#
# Locating floor plane and reorientate to x-y plane
# No of points: 24304
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 13577
#
# Perform mesh clustering to remove small objects
# Range: [ 9.01512027 14.94696295  7.25850042]
# eps: 0.1
# min_points 10
# Counter:
# Counter({-1: 13567, 0: 10})
# Only 1 cluster found!
# No of points: 13577
# Precompute neighbors.[========================================] 100%
#
# Scaling longest x-y axis based on foot length: 23.5cm
# Scaling Factor: 1.6 - Estimated Distance: 14.9 - Target Length: 23.5
# No of points: 13577
#
# Cropping mesh from the top
# Max value: 11.412001248876845
# No of points: 13577
#
# Cleaning output
# No of points: 13574
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1044.914 cm3
#
# ############################################################
# Subject 17 - 17D0L - Feet length 21.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [21.5, 21.5, 21.5, 21.5, 22.0] - 21.5
#
# Load Mesh
# Number of Vertices:  79199
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 79199
#
# Locating floor plane and reorientate to x-y plane
# No of points: 79199
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 52446
#
# Perform mesh clustering to remove small objects
# Range: [1.81044402 3.18113048 1.13193778]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({1: 46586, 2: 3572, 0: 2135, 3: 153})
# Precompute neighbors.[================>           4 cluster found!%
# Precompute neighbors.[========================================] 100%
# Clustering[========================================] 100%
# No of points: 46586
#
# Scaling longest x-y axis based on foot length: 21.5cm
# Scaling Factor: 11.5 - Estimated Distance: 1.9 - Target Length: 21.5
# No of points: 46586
#
# Cropping mesh from the top
# Max value: 13.035332932093405
# No of points: 45082
#
# Cleaning output
# No of points: 45074
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1244.126 cm3
#
# ############################################################
# Subject 17 - 17D0R - Feet length 22.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [22.0, 22.5, 23.5, 21.5, 22.5] - 22.0
#
# Load Mesh
# Number of Vertices:  35936
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 35936
#
# Locating floor plane and reorientate to x-y plane
# No of points: 35936
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 30996
#
# Perform mesh clustering to remove small objects
# Range: [3.57726182 3.45051893 1.3777304 ]
# eps: 0.1
# min_points 10
# Precompute neighbors.[================>           Counter:    ] 37%
# Counter({0: 24244, 3: 6476, 2: 236, 1: 31, -1: 9})
# 4 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 24244===============================>] 97%
#
# Scaling longest x-y axis based on foot length: 22.0cm
# Scaling Factor: 11.6 - Estimated Distance: 1.9 - Target Length: 22.0
# No of points: 24244
#
# Cropping mesh from the top
# Max value: 14.75040760475067
# No of points: 22804
#
# Cleaning output
# No of points: 22802
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1732.162 cm3
#
# ############################################################
# Subject 17 - 17D1L - Feet length 21.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [21.5, 21.5, 21.5, 21.5, 22.0] - 21.5
#
# Load Mesh
# Number of Vertices:  39939
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 39939
#
# Locating floor plane and reorientate to x-y plane
# No of points: 39939
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 23988
#
# Perform mesh clustering to remove small objects
# Range: [10.06854803  5.73531042  3.42989267]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[==>                                     ] 5%
# Counter({0: 19650, 1: 1675, -1: 1457, 22: 162, 9: 108, 11: 71, 26: 71, 5: 69, 10: 65, 2: 52, 13: 46, 3: 43, 12: 43, 25: 39, 15: 37, 4: 35, 27: 33, 21: 32, 19: 29, 8: 23, 29: 22, 17: 19, 33: 19, 16: 17, 32: 16, 20: 15, 6: 13, 36: 13, 31: 12, 23: 12, 30: 12, 7: 11, 24: 11, 18: 10, 34: 10, 35: 10, 37: 10, 14: 8, 28: 8})
# 38 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 19650=============================>  ] 92%
#
# Scaling longest x-y axis based on foot length: 21.5cm
# Scaling Factor: 5.4 - Estimated Distance: 4.0 - Target Length: 21.5
# No of points: 19650
#
# Cropping mesh from the top
# Max value: 15.237018794788582
# No of points: 17275
#
# Cleaning output
# No of points: 17275
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1100.766 cm3
#
# ############################################################
# Subject 17 - 17D1R - Feet length 22.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [22.0, 22.5, 23.5, 21.5, 22.5] - 22.0
#
# Load Mesh
# Number of Vertices:  58679
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 58679
#
# Locating floor plane and reorientate to x-y plane
# No of points: 58679
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 26766
#
# Perform mesh clustering to remove small objects
# Range: [2.20486202 1.57467996 1.04176486]
# eps: 0.1
# min_points 10
# Precompute neighbors.[================>           Counter:    ] 37%
# Counter({0: 25339, 1: 1427})
# 2 cluster found!
# Precompute neighbors.[========================================] 100%
# Clustering[========================================] 100%
# No of points: 25339
#
# Scaling longest x-y axis based on foot length: 22.0cm
# Scaling Factor: 18.9 - Estimated Distance: 1.2 - Target Length: 22.0
# No of points: 25339
#
# Cropping mesh from the top
# Max value: 19.67765073046305
# No of points: 19961
#
# Cleaning output
# No of points: 19961
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1745.042 cm3
#
# ############################################################
# Subject 17 - 17D2L - Feet length 21.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [21.5, 21.5, 21.5, 21.5, 22.0] - 21.5
#
# Load Mesh
# Number of Vertices:  87060
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 82179
#
# Locating floor plane and reorientate to x-y plane
# No of points: 82179
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 46541
#
# Perform mesh clustering to remove small objects
# Range: [8.07645594 5.65403569 1.43807601]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[==>                                     ] 5%
# Counter({0: 39989, 1: 6164, 3: 207, 5: 126, 4: 38, 2: 17})
# 6 cluster found!
# Precompute neighbors.[========================================] 100%
# Clustering[========================================] 100%
# No of points: 39989
#
# Scaling longest x-y axis based on foot length: 21.5cm
# Scaling Factor: 8.1 - Estimated Distance: 2.6 - Target Length: 21.5
# No of points: 39989
#
# Cropping mesh from the top
# Max value: 11.713443506133377
# No of points: 39989
#
# Cleaning output
# No of points: 39989
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1099.39 cm3
#
# ############################################################
# Subject 17 - 17D2R - Feet length 22.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [22.0, 22.5, 23.5, 21.5, 22.5] - 22.0
#
# Load Mesh
# Number of Vertices:  40451
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 40451
#
# Locating floor plane and reorientate to x-y plane
# No of points: 40451
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 27731
#
# Perform mesh clustering to remove small objects
# Range: [0.71557778 1.13304051 0.63911072]
# eps: 0.1
# min_points 10
# Precompute neighbors.[========================================] 100%  ] 5%
# Clustering[======>                                 ] 15%
# Counter({0: 27731})
# Only 1 cluster found!
# No of points: 27731
# Clustering[========================================] 100%
#
# Scaling longest x-y axis based on foot length: 22.0cm
# Scaling Factor: 19.4 - Estimated Distance: 1.1 - Target Length: 22.0
# No of points: 27731
#
# Cropping mesh from the top
# Max value: 12.40947319049514
# No of points: 27526
#
# Cleaning output
# No of points: 27526
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1304.412 cm3
#
# ############################################################
# Subject 17 - 17D3L - Feet length 21.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [21.5, 21.5, 21.5, 21.5, 22.0] - 21.5
#
# Load Mesh
# Number of Vertices:  65501
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 65006
#
# Locating floor plane and reorientate to x-y plane
# No of points: 65006
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 43182
#
# Perform mesh clustering to remove small objects
# Range: [3.37653314 2.47968193 1.57741557]
# eps: 0.1
# min_points 10
# Precompute neighbors.[================>           Counter:    ] 37%
# Counter({0: 42746, 2: 410, 1: 24, -1: 2})
# 3 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 42746===============================>] 97%
#
# Scaling longest x-y axis based on foot length: 21.5cm
# Scaling Factor: 8.7 - Estimated Distance: 2.5 - Target Length: 21.5
# No of points: 42746
#
# Cropping mesh from the top
# Max value: 13.676929416345164
# No of points: 40208
#
# Cleaning output
# No of points: 40206
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1443.798 cm3
#
# ############################################################
# Subject 17 - 17D3R - Feet length 22.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [22.0, 22.5, 23.5, 21.5, 22.5] - 22.0
#
# Load Mesh
# Number of Vertices:  96327
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 96327
#
# Locating floor plane and reorientate to x-y plane
# No of points: 96327
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 65360
#
# Perform mesh clustering to remove small objects
# Range: [2.12430381 3.20999731 0.88672948]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({0: 62090, 1: 2146, 3: 647, 2: 452, 4: 25})
# Precompute neighbors.[================>           5 cluster found!%
# Precompute neighbors.[========================================] 100%
# Clustering[========================================] 100%
# No of points: 62090
#
# Scaling longest x-y axis based on foot length: 22.0cm
# Scaling Factor: 13.2 - Estimated Distance: 1.7 - Target Length: 22.0
# No of points: 62090
#
# Cropping mesh from the top
# Max value: 11.719906890198356
# No of points: 62090
#
# Cleaning output
# No of points: 62088
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1048.932 cm3
#
# ############################################################
# Subject 17 - 17D4L - Feet length 21.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [21.5, 21.5, 21.5, 21.5, 22.0] - 21.5
#
# Load Mesh
# Number of Vertices:  40599
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 40599
#
# Locating floor plane and reorientate to x-y plane
# No of points: 40599
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 31635
#
# Perform mesh clustering to remove small objects
# Range: [11.07218669 12.95919285  4.02119794]
# eps: 0.1
# min_points 10
# Precompute neighbors.[==============================>         ] 75%Counter:
# Counter({0: 27196, -1: 3667, 8: 94, 5: 47, 7: 39, 2: 36, 34: 35, 13: 27, 9: 26, 20: 25, 6: 23, 14: 23, 17: 23, 3: 20, 30: 20, 31: 19, 12: 18, 22: 18, 33: 18, 4: 17, 26: 17, 10: 16, 11: 16, 29: 16, 1: 15, 25: 15, 15: 15, 32: 14, 35: 14, 24: 14, 21: 13, 18: 11, 19: 10, 27: 10, 23: 10, 36: 10, 28: 10, 37: 10, 16: 8})
# 38 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 27196===========================>    ] 87%
#
# Scaling longest x-y axis based on foot length: 21.5cm
# Scaling Factor: 4.3 - Estimated Distance: 5.0 - Target Length: 21.5
# No of points: 27196
#
# Cropping mesh from the top
# Max value: 17.12369812436771
# No of points: 24878
#
# Cleaning output
# No of points: 24877
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1690.581 cm3
#
# ############################################################
# Subject 17 - 17D4R - Feet length 22.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [22.0, 22.5, 23.5, 21.5, 22.5] - 22.0
#
# Load Mesh
# Number of Vertices:  68092
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 68092
#
# Locating floor plane and reorientate to x-y plane
# No of points: 68092
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 32330
#
# Perform mesh clustering to remove small objects
# Range: [7.8324263  8.15705022 2.85410365]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({0: 20035, 1: 6786, 2: 4984, 3: 428, -1: 97})
# 4 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 20035===============================>] 97%
#
# Scaling longest x-y axis based on foot length: 22.0cm
# Scaling Factor: 9.6 - Estimated Distance: 2.3 - Target Length: 22.0
# No of points: 20035
#
# Cropping mesh from the top
# Max value: 21.282757039387725
# No of points: 14867
#
# Cleaning output
# No of points: 14867
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1475.019 cm3
#
# ############################################################
# ...
# No of points: 10763
#
# Cleaning output
# No of points: 10763
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1315.397 cm3
#
# ############################################################
# Subject 29 - 29D0L - Feet length 25.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.0, 23.0] - 25.0
#
# Load Mesh
# Number of Vertices:  38167
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 38167
#
# Locating floor plane and reorientate to x-y plane
# No of points: 38167
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 20292
#
# Perform mesh clustering to remove small objects
# Range: [2.25926754 3.01532065 1.69852657]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({0: 17359, 1: 2933})
# 2 cluster found!
# Precompute neighbors.[========================================] 100%
# Clustering[========================================] 100%
# No of points: 17359
#
# Scaling longest x-y axis based on foot length: 25.0cm
# Scaling Factor: 11.5 - Estimated Distance: 2.2 - Target Length: 25.0
# No of points: 17359
#
# Cropping mesh from the top
# Max value: 19.570117949039556
# No of points: 12604
#
# Cleaning output
# No of points: 12604
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 2103.202 cm3
#
# ############################################################
# Subject 29 - 29D0R - Feet length 25.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.0, 23.0] - 25.0
#
# Load Mesh
# Number of Vertices:  42552
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 42552
#
# Locating floor plane and reorientate to x-y plane
# No of points: 42552
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 21095
#
# Perform mesh clustering to remove small objects
# Range: [2.63788263 1.71098515 1.62613582]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({0: 21095})
# Only 1 cluster found!
# No of points: 21095
# Precompute neighbors.[========================================] 100%
# Clustering[========================================] 100%
#
# Scaling longest x-y axis based on foot length: 25.0cm
# Scaling Factor: 9.5 - Estimated Distance: 2.6 - Target Length: 25.0
# No of points: 21095
#
# Cropping mesh from the top
# Max value: 15.411373922147407
# No of points: 19322
#
# Cleaning output
# No of points: 19322
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1665.556 cm3
#
# ############################################################
# Subject 29 - 29D1L - Feet length 25.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.0, 23.0] - 25.0
#
# Load Mesh
# Number of Vertices:  33462
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 33462
#
# Locating floor plane and reorientate to x-y plane
# No of points: 33462
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 13108
#
# Perform mesh clustering to remove small objects
# Range: [2.02852419 3.24657152 1.32303308]
# eps: 0.1
# min_points 10
# Precompute neighbors.[========================================] 100%
# Counter:ng[=======================================>] 97%
# Counter({0: 13040, 1: 62, -1: 6})
# 2 cluster found!
# No of points: 13040
#
# Scaling longest x-y axis based on foot length: 25.0cm
# Scaling Factor: 11.0 - Estimated Distance: 2.3 - Target Length: 25.0
# No of points: 13040
#
# Cropping mesh from the top
# Max value: 14.558168352600845
# No of points: 12321
#
# Cleaning output
# No of points: 12320
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1567.853 cm3
#
# ############################################################
# Subject 29 - 29D1R - Feet length 25.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [25.0, 23.0] - 25.0
#
# Load Mesh
# Number of Vertices:  33363
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 33363
#
# Locating floor plane and reorientate to x-y plane
# No of points: 33363
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 12115
#
# Perform mesh clustering to remove small objects
# Range: [2.99537939 3.30935373 1.79846743]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({0: 12111, -1: 4})
# Only 1 cluster found!
# No of points: 12115
# Precompute neighbors.[========================================] 100%
# Clustering[=======================================>] 97%
# Scaling longest x-y axis based on foot length: 25.0cm
# Scaling Factor: 7.6 - Estimated Distance: 3.3 - Target Length: 25.0
# No of points: 12115
#
# Cropping mesh from the top
# Max value: 13.58624350658482
# No of points: 11659
#
# Cleaning output
# No of points: 11658
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1803.976 cm3
#
# ############################################################
# Subject 35 - 35D0L - Feet length 27.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [27.0, 26.5, 26.5] - 27.0
#
# Load Mesh
# Number of Vertices:  50571
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 50571
#
# Locating floor plane and reorientate to x-y plane
# No of points: 50571
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 28546
#
# Perform mesh clustering to remove small objects
# Range: [1.90796803 0.97306947 1.36295464]
# eps: 0.1
# min_points 10
# Counter:
# Counter({0: 28546})
# Only 1 cluster found!
# No of points: 28546
# Precompute neighbors.[=>                                      ] 2%
# Scaling longest x-y axis based on foot length: 27.0cm
# Precompute neighbors.[========================================] 100%
# Clustering[========================================] 100%
# Scaling Factor: 14.2 - Estimated Distance: 1.9 - Target Length: 27.0
# No of points: 28546
#
# Cropping mesh from the top
# Max value: 19.287417105554987
# No of points: 22323
#
# Cleaning output
# No of points: 22323
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1942.962 cm3
#
# ############################################################
# Subject 35 - 35D0R - Feet length 26.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [26.0, 26.0, 26.0] - 26.0
#
# Load Mesh
# Number of Vertices:  14334
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 14334
#
# Locating floor plane and reorientate to x-y plane
# No of points: 14334
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 10629
#
# Perform mesh clustering to remove small objects
# Range: [5.92092939 5.58288274 5.94581993]
# eps: 0.1
# min_points 10
# Counter:
# Counter({-1: 3901, 6: 3187, 2: 1025, 10: 414, 8: 358, 1: 186, 7: 162, 4: 83, 18: 80, 31: 72, 0: 67, 14: 66, 36: 64, 19: 64, 21: 60, 5: 56, 11: 45, 42: 44, 3: 29, 29: 26, 17: 25, 33: 23, 35: 23, 12: 22, 56: 22, 48: 21, 9: 21, 20: 21, 45: 19, 43: 19, 15: 18, 28: 17, 13: 17, 26: 15, 38: 14, 16: 14, 24: 14, 59: 14, 27: 14, 25: 13, 66: 13, 60: 12, 23: 12, 64: 12, 68: 11, 37: 11, 41: 11, 61: 11, 44: 11, 40: 10, 54: 10, 55: 10, 62: 10, 34: 10, 67: 10, 65: 10, 49: 10, 52: 9, 53: 9, 32: 9, 30: 8, 51: 8, 39: 8, 22: 7, 63: 7, 57: 7, 47: 7, 58: 5, 50: 5, 46: 1})
# 69 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 3187==================>              ] 62%
#
# Scaling longest x-y axis based on foot length: 26.0cm
# Scaling Factor: 7.8 - Estimated Distance: 3.3 - Target Length: 26.0
# No of points: 3187
#
# Cropping mesh from the top
# Max value: 20.836810525054524
# No of points: 2438
#
# Cleaning output
# No of points: 2434
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1439.137 cm3
#
# ############################################################
# Subject 35 - 35D1L - Feet length 27.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [27.0, 26.5, 26.5] - 27.0
#
# Load Mesh
# Number of Vertices:  43163
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 43163
#
# Locating floor plane and reorientate to x-y plane
# No of points: 43163
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 20782
#
# Perform mesh clustering to remove small objects
# Range: [2.98620576 1.42805242 2.18727401]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({0: 20760, 1: 18, -1: 4})
# 2 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 20760===============================>] 97%
#
# Scaling longest x-y axis based on foot length: 27.0cm
# Scaling Factor: 9.0 - Estimated Distance: 3.0 - Target Length: 27.0
# No of points: 20760
#
# Cropping mesh from the top
# Max value: 19.776399547580436
# No of points: 15614
#
# Cleaning output
# No of points: 15614
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1623.791 cm3
#
# ############################################################
# Subject 35 - 35D1R - Feet length 26.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [26.0, 26.0, 26.0] - 26.0
#
# Load Mesh
# Number of Vertices:  29045
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 29045
#
# Locating floor plane and reorientate to x-y plane
# No of points: 29045
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 12054
#
# Perform mesh clustering to remove small objects
# Range: [10.29659006  5.37060266  3.80819897]
# eps: 0.1
# min_points 10
# Precompute neighbors.[========================================] 100%
# Counter:ng[====================================>   ] 90%
# Counter({0: 10843, -1: 1087, 1: 50, 2: 31, 5: 20, 3: 10, 6: 8, 4: 5})
# 7 cluster found!
# No of points: 10843
#
# Scaling longest x-y axis based on foot length: 26.0cm
# Scaling Factor: 6.2 - Estimated Distance: 4.2 - Target Length: 26.0
# No of points: 10843
#
# Cropping mesh from the top
# Max value: 23.695819842138864
# No of points: 8107
#
# Cleaning output
# No of points: 8107
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1563.097 cm3
#
# ############################################################
# Subject 35 - 35D2L - Feet length 27.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [27.0, 26.5, 26.5] - 27.0
#
# Load Mesh
# Number of Vertices:  49765
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 49765
#
# Locating floor plane and reorientate to x-y plane
# No of points: 49765
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 26607
#
# Perform mesh clustering to remove small objects
# Range: [3.20018278 6.38422007 3.93568066]
# eps: 0.1
# min_points 10
# Precompute neighbors.[========================================] 100%
# Counter:ng[======================================> ] 95%
# Counter({0: 25235, -1: 1303, 1: 21, 2: 18, 4: 16, 3: 14})
# 5 cluster found!
# No of points: 25235
#
# Scaling longest x-y axis based on foot length: 27.0cm
# Scaling Factor: 4.2 - Estimated Distance: 6.4 - Target Length: 27.0
# No of points: 25235
#
# Cropping mesh from the top
# Max value: 16.64469215133377
# No of points: 22106
#
# Cleaning output
# No of points: 22106
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1729.689 cm3
#
# ############################################################
# Subject 35 - 35D2R - Feet length 26.0cm
# ############################################################
# scene_dense_mesh_refine.ply
# [26.0, 26.0, 26.0] - 26.0
#
# Load Mesh
# Number of Vertices:  8683
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 8683
#
# Locating floor plane and reorientate to x-y plane
# No of points: 8683
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 8038
#
# Perform mesh clustering to remove small objects
# Range: [1.08472798 1.96118045 0.75309489]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({0: 8038})
# Only 1 cluster found!
# No of points: 8038
# Precompute neighbors.[================>                       ] 37%
# Scaling longest x-y axis based on foot length: 26.0cm
# Precompute neighbors.[========================================] 100%
# Clustering[========================================] 100%
# Scaling Factor: 13.3 - Estimated Distance: 2.0 - Target Length: 26.0
# No of points: 8038
#
# Cropping mesh from the top
# Max value: 9.984021193583219
# No of points: 8038
#
# Cleaning output
# No of points: 8038
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1086.085 cm3
#
# ############################################################
# Subject 46 - 46D0L - Feet length 24.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [24.5] - 24.5
#
# Load Mesh
# Number of Vertices:  8431
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 8431
#
# Locating floor plane and reorientate to x-y plane
# No of points: 8431
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 2134
#
# Perform mesh clustering to remove small objects
# Range: [1.32761645 0.99770075 1.61183053]
# eps: 0.1
# min_points 10
# Counter:
# Counter({0: 2027, -1: 61, 2: 19, 1: 17, 3: 10})
# 4 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 2027===============================> ] 95%
#
# Scaling longest x-y axis based on foot length: 24.5cm
# Scaling Factor: 18.6 - Estimated Distance: 1.3 - Target Length: 24.5
# No of points: 2027
#
# Cropping mesh from the top
# Max value: 25.576181695164067
# No of points: 1382
#
# Cleaning output
# No of points: 1382
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 2279.473 cm3
#
# ############################################################
# Subject 46 - 46D0R - Feet length 24.5cm
# ############################################################
# scene_dense_mesh_refine.ply
# [24.5] - 24.5
#
# Load Mesh
# Number of Vertices:  148
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 148
#
# Locating floor plane and reorientate to x-y plane
# No of points: 148
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 116
#
# Perform mesh clustering to remove small objects
# Range: [2.25220476 3.16119452 0.66079039]
# eps: 0.1
# min_points 10
# Counter:
# Counter({-1: 116})
# Only 1 cluster found!
# No of points: 116
#
# Scaling longest x-y axis based on foot length: 24.5cm
# Scaling Factor: 7.8 - Estimated Distance: 3.2 - Target Length: 24.5
# No of points: 116
#
# Cropping mesh from the top
# Max value: 5.1212807411221455
# No of points: 116
#
# Cleaning output
# No of points: 116
#
# Saving Final Mesh
# Precompute neighbors.[========================================] 100%
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 910.823 cm3
#
# ############################################################
# Subject 74 - 74D0R - Feet length 25cm
# ############################################################
# scene_dense_mesh_refine.ply
# Series([], Name: Right foot length (cm), dtype: object) - 25
#
# Load Mesh
# Number of Vertices:  157621
#
# Removing isolated vertices using DBSCAN clustering
# Remaining vertices: 157614
#
# Locating floor plane and reorientate to x-y plane
# No of points: 157614
#
# Cropping mesh below the bottom 10th percentile of Z values
# No of points: 56517
#
# Perform mesh clustering to remove small objects
# Range: [6.8826145  6.3147428  2.69815903]
# eps: 0.1
# min_points 10
# Counter:te neighbors.[=>                                      ] 2%
# Counter({1: 36256, 0: 20236, 2: 17, -1: 8})
# 3 cluster found!
# Precompute neighbors.[========================================] 100%
# No of points: 36256===============================>] 97%
#
# Scaling longest x-y axis based on foot length: 25cm
# Scaling Factor: 5.5 - Estimated Distance: 4.5 - Target Length: 25
# No of points: 36256
#
# Cropping mesh from the top
# Max value: 14.937099796644764
# No of points: 35478
#
# Cleaning output
# No of points: 35478
#
# Saving Final Mesh
#
# Calculating Volume
# scene_dense_mesh_refine.ply - Volume: 1195.349 cm3
