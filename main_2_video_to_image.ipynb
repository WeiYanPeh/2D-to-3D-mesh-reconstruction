# %%
# !pip3 install moviepy piexif --break-system-packages

# %% [markdown]
# # Libraries

# %%
import os
import cv2
import itertools

import numpy as np
import pandas as pd

from collections import Counter
from pprint import pprint
from tqdm import tqdm

from moviepy import VideoFileClip
# from moviepy.editor import VideoFileClip
from PIL import Image
from PIL.TiffImagePlugin import ImageFileDirectory_v2

# %% [markdown]
# # User Defined Functions

# %%
############################################################
# Get a list of all files and folders in the specified directory
############################################################
def get_folders_in_directory(directory):
    items = os.listdir(directory)
    
    # Filter out the items that are folders
    folders = [item for item in items if os.path.isdir(os.path.join(directory, item))]    
    return folders

############################################################
# Get a list of all files and folders in the specified directory
############################################################
def list_directory_contents(directory):
    items = os.listdir(directory)    
    return items

############################################################
# Perform image rotation
############################################################
def correct_rotation(frame, rotateCode):
    return cv2.rotate(frame, rotateCode)

############################################################
# Get exactly k frames
############################################################
def check_k_frames(total_frames, n):
    interval = total_frames // n
    extracted_frames = []
    for i in range(n):
        frame_index = i * interval
        extracted_frames.append(frame_index)
    return extracted_frames

############################################################
# Get n frame per second
############################################################
def get_n_frames_per_second(total_frames, fps, n):
    frames_per_second = []
    for second in range(total_frames // fps):
        interval = fps // n
        for i in range(n):
            frame_index = second * fps + i * interval
            if frame_index < total_frames:
                frames_per_second.append(frame_index)
    return frames_per_second


############################################################
# Extract n frames from videos
############################################################
def extract_frames(video_path, output_folder, fps, scale_percent, max_frames):
    # Set an approximate maximum frames allowed
    # Default 30, change to 60 to see if more images helps    
    fps = int(fps)
    
    # Open the video file
    video = cv2.VideoCapture(video_path)
    
    # Check if the video file opened successfully
    if not video.isOpened():
        print("Error: Could not open video file.")
        return
    
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    # list_frames = check_k_frames(total_frames, max_frames)
    list_frames = get_n_frames_per_second(total_frames, fps, max_frames)
    
    frame_count = 0
    saved_frame_count = 0
    
    while True:
        # Read a frame from the video
        ret, frame = video.read()
        
        # If the frame was not read successfully, break the loop
        if not ret:
            break
        
        # Correct the rotation of the frame if needed
        rotateCode = cv2.ROTATE_90_COUNTERCLOCKWISE  # Change this based on the video's rotation metadata
        frame = correct_rotation(frame, rotateCode)
        
        width = int(frame.shape[1] * scale_percent / 100)
        height = int(frame.shape[0] * scale_percent / 100)
        dim = (width, height)
        frame = cv2.resize(frame, dim, interpolation=cv2.INTER_AREA)
        
        # Save every 10th frame as an image file
        if frame_count in list_frames:
            frame_filename = os.path.join(output_folder, f"frame_{saved_frame_count:04d}.jpeg")
            cv2.imwrite(frame_filename, frame)
            saved_frame_count += 1
        
        frame_count += 1

    # Release the video file
    video.release()
    
    return saved_frame_count


############################################################
# Get video duration
############################################################
def get_video_duration(file_path):
    video = cv2.VideoCapture(file_path)
    fps = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    duration = frame_count / fps
    return duration, frame_count, fps

# %% [markdown]
# # Load folder

# %%
# Specify the directory path
directory_path = f'/home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE'

# Get the list of folders in the directory
folders = get_folders_in_directory(directory_path)
folders = [x for x in folders if 'Subject' in x]

folders.sort()

# Print the list of folders
print(folders)
print(len(folders))
# Out:
# ['1. Subject 1', '10. Subject 10', '11. Subject 11', '12. Subject 12', '13. Subject 13', '14. Subject 14', '15. Subject 15', '16. Subject 16', '17. Subject 17', '18. Subject 18', '19. Subject 19', '2. Subject 2', '20. Subject 20', '21. Subject 21', '22. Subject 22', '23. Subject 23', '24. Subject 24', '25. Subject 25', '26. Subject 26', '27. Subject 27', '28. Subject 28', '29. Subject 29', '3. Subject 3', '30. Subject 30', '31. Subject 31', '32. Subject 32', '33. Subject 33', '34. Subject 34', '35. Subject 35', '36. Subject 36', '37. Subject 37', '38. Subject 38', '39. Subject 39', '4. Subject 4', '40. Subject 40', '41. Subject 41', '42. Subject 42', '43. Subject 43', '44. Subject 44', '45. Subject 45', '46. Subject 46', '47. Subject 47', '48. Subject 48', '49. Subject 49', '5. Subject 5', '50. Subject 50', '51. Subject 51', '52. Subject 52', '53. Subject 53', '54. Subject 54', '55. Subject 55', '56. Subject 56', '57. Subject 57', '58. Subject 58', '59. Subject 59', '6. Subject 6', '60. Subject 60', '61. Subject 61', '62. Subject 62', '63. Subject 63', '64. Subject 64', '65. Subject 65', '66. Subject 66', '67. Subject 67', '68. Subject 68', '69. Subject 69', '7. Subject 7', '70. Subject 70', '71. Subject 71', '8. Subject 8', '9. Subject 9']
# 71

# %% [markdown]
# # Get videos counts

# %%
list_video_counter = []
for folder in folders:
    folder_path = os.path.join(directory_path, folder)
    
    subject = folder.split('.')[0]
    
    # Get the list of files and folders in the directory
    contents = list_directory_contents(folder_path)
    contents = [x for x in contents if ':Zone.Identifier' not in x]

    print('#'*60)
    print('Subject', subject, ':', contents)
    list_video_counter.append(len(contents))
# Out:
# ############################################################
# Subject 1 : ['1D0L.mp4', '1D0R.mp4']
# ############################################################
# Subject 10 : ['10D2L.mp4', '10D1R.mp4', '10D1L.mp4', '10D0R.mp4', '10D2R.mp4', '10D0L.mp4']
# ############################################################
# Subject 11 : ['11D0L.mp4', '11D2R.mp4', '11D2L.mp4', '11D1R.mp4', '11D1L.mp4', '11D0R.mp4']
# ############################################################
# Subject 12 : ['12D0L.mp4', '12D0R.mp4']
# ############################################################
# Subject 13 : ['13D1L.mp4', '13D0L.mp4', '13D2L.mp4', '13D5L.mp4']
# ############################################################
# Subject 14 : ['14D1L.mp4', '14D1R.mp4', '14D0R.mp4', '14D0L.mp4']
# ############################################################
# Subject 15 : ['15D2L.mp4', '15D1L.mp4', '15D0R.mp4', '15D0L.mp4', '15D1R.mp4', '15D2R.mp4']
# ############################################################
# Subject 16 : ['16D1R.mp4', '16D0R.mp4', '16D0L.mp4', '16D1L.mp4']
# ############################################################
# Subject 17 : ['17D2R.mp4', '17D1R.mp4', '17D2L.mp4', '17D3R.mp4', '17D4R.mp4', '17D3L.mp4', '17D4L.mp4', '17D1L.mp4', '17D0L.mp4', '17D0R.mp4']
# ############################################################
# Subject 18 : ['18D1L.mp4', '18D0L.mp4', '18D0R.mp4', '18D1R.mp4']
# ############################################################
# Subject 19 : ['19D3L.mp4', '19D1L.mp4', '19D0L.mp4', '19D2R.mp4', '19D1R.mp4', '19D0R.mp4', '19D2L.mp4', '19D3R.mp4']
# ############################################################
# Subject 2 : ['2D4R.mp4', '2D0R.mp4', '2D5R.mp4', '2D0L.mp4', '2D4L.mp4', '2D5L.mp4']
# ############################################################
# Subject 20 : ['20D0L.mp4', '20D3L.mp4', '20D2L.mp4', '20D1L.mp4']
# ############################################################
# Subject 21 : ['21D0R.mp4', '21D0L.mp4']
# ############################################################
# Subject 22 : ['22D2R.mp4', '22D1L.mp4', '22D0R.mp4', '22D2L.mp4', '22D0L.mp4', '22D1R.mp4', '22D0L_2.mp4']
# ############################################################
# Subject 23 : ['23D1L.mp4', '23D0L.mp4', '23D1R.mp4', '23D0R.mp4']
# ############################################################
# Subject 24 : ['24D3L.mp4', '24D2R.mp4', '24D3R.mp4', '24D2L.mp4', '24D0L.mp4', '24D0R.mp4']
# ############################################################
# Subject 25 : ['25D2R.mp4', '25D0R.mp4', '25D1L.mp4', '25D1R.mp4', '25D3L.mp4', '25D3R.mp4', '25D0L.mp4', '25D2L.mp4']
# ############################################################
# Subject 26 : ['26D3L.mp4', '26D2L.mp4', '26D3R.mp4', '26D0L.mp4', '26D2R.mp4', '26D1R.mp4', '26D1L.mp4', '26D0R.mp4']
# ############################################################
# Subject 27 : ['27D0L.mp4', '27D0R.mp4', '27D1L.mp4', '27D1R.mp4']
# ############################################################
# Subject 28 : ['28D3L.mp4', '28D2R.mp4', '28D0L.mp4', '28D1L.mp4', '28D1R.mp4', '28D3R.mp4', '28D2L.mp4', '28D0R.mp4']
# ############################################################
# Subject 29 : ['29D0L.mp4', '29D1L.mp4', '29D1R.mp4', '29D0R.mp4']
# ############################################################
# Subject 3 : ['3D3R.mp4', '3D0L.mp4', '3D2R.mp4', '3D2L.mp4', '3D1R.mp4', '3D1L.mp4', '3D3L.mp4', '3D0R.mp4']
# ############################################################
# Subject 30 : ['30D3R.mp4', '30D3L.mp4', '30D0L.mp4', '30D0R.mp4']
# ############################################################
# Subject 31 : ['31D3L.mp4', '31D0L.mp4', '31D0R.mp4', '31D4L.mp4', '31D1R.mp4', '31D1L.mp4', '31D3R.mp4', '31D2L.mp4', '31D4R.mp4', '31D2R.mp4']
# ############################################################
# Subject 32 : ['32D1R.mp4', '32D1L.mp4', '32D0R.mp4', '32D2L.mp4', '32D0L.mp4', '32D2R.mp4']
# ############################################################
# Subject 33 : ['33D1R.mp4', '33D2L.mp4', '33D4L.mp4', '33D2R.mp4', '33D1L.mp4', '33D0R.mp4', '33d0L.mp4', '33D3R.mp4', '33d3L.mp4', '33D4R.mp4']
# ############################################################
# Subject 34 : ['34D4L.mp4', '34D3L.mp4', '34D1L.mp4', '34D0L.mp4', '34D0R.mp4', '34D3R.mp4', '34D1R.mp4', '34D4R.mp4']
# ############################################################
# Subject 35 : ['35D1R.mp4', '35D2L.mp4', '35D0L.mp4', '35D0R.mp4', '35D1L.mp4', '35D2R.mp4']
# ############################################################
# Subject 36 : ['36D0R.mp4', '36D1R.mp4', '36D0L.mp4', '36D1L.mp4']
# ############################################################
# Subject 37 : ['37D0L.mp4', '37D0R.mp4']
# ############################################################
# Subject 38 : ['38D0R.mp4', '38D2L.mp4', '38D1R.mp4', '38D2R.mp4', '38D0L.mp4', '38D1L.mp4']
# ############################################################
# Subject 39 : ['39D0L.mp4', '39D1L.mp4', '39D4R.mp4', '39D5L.mp4', '39D0R.mp4', '39D5R.mp4', '39D4L.mp4', '39D1R.mp4']
# ############################################################
# Subject 4 : ['4D2L.mp4', '4D1R.mp4', '4D2R.mp4', '4D1L.mp4', '4D0L.mp4', '4D0R.mp4']
# ############################################################
# Subject 40 : ['40D0R.mp4', '40D0L.mp4']
# ############################################################
# Subject 41 : ['41D0R.mp4', '41D0L.mp4']
# ############################################################
# Subject 42 : ['42D2R.mp4', '42D2L.mp4', '42D0R.mp4', '42D0L.mp4', '42D1L.mp4', '42D1R.mp4']
# ############################################################
# Subject 43 : ['43D0L.mp4', '43D4L.mp4', '43D4R.mp4', '43D1L.mp4', '43D0R.mp4', '43D2R.mp4', '43D2L.mp4', '43D3L.mp4', '43D1R.mp4', '43D3R.mp4']
# ############################################################
# Subject 44 : ['44D0L.mp4', '44D3L.mp4', '44D3R.mp4', '44D2R.mp4', '44D4R.mp4', '44D2L.mp4', '44D1R.mp4', '44D0R.mp4', '44D4L.mp4', '44D1L.mp4']
# ############################################################
# Subject 45 : ['45D2L.mp4', '45D5R.mp4', '45D5L.mp4', '45D2R.mp4', '45D1R.mp4', '45D0L.mp4', '45D1L.mp4', '45D0R.mp4']
# ############################################################
# Subject 46 : ['46D0L.mp4', '46D0R.mp4']
# ############################################################
# Subject 47 : ['47D1R.mp4', '47D1L.mp4', '47D4L.mp4', '47D0L.mp4', '47D3R.mp4', '47D3L.mp4', '47D0R.mp4', '47D2L.mp4', '47D4R.mp4', '47D2R.mp4']
# ############################################################
# Subject 48 : ['48D0L.mp4', '48D3L.mp4', '48D0R.mp4', '48D2L.mp4', '48D3R.mp4', '48D2R.mp4', '48D1R.mp4', '48D1L.mp4']
# ############################################################
# Subject 49 : ['49D1L.mp4', '49D0L.mp4', '49D1R.mp4', '49D0R.mp4']
# ############################################################
# Subject 5 : ['5D0R.mp4', '5D2L.mp4', '5D1R.mp4', '5D2R.mp4', '5D3R.mp4', '5D1L.mp4', '5D0L.mp4', '5D3L.mp4']
# ############################################################
# Subject 50 : ['50D4L.mp4', '50D0L.mp4', '50D1R.mp4', '50D1L.mp4', '50D3L.mp4', '50D0R.mp4', '50D4R.mp4', '50D2R.mp4', '50D2L.mp4', '50D3R.mp4']
# ############################################################
# Subject 51 : ['51D0L.mp4', '51D0R.mp4']
# ############################################################
# Subject 52 : ['52D1L.mp4', '52D0R.mp4', '52D2L.mp4', '52D2R.mp4', '52D0L.mp4', '52D1R.mp4']
# ############################################################
# Subject 53 : ['53D0L.mp4', '53D1R.mp4', '53D1L.mp4', '53D2L.mp4', '53D2R.mp4', '53D0R.mp4']
# ############################################################
# Subject 54 : ['54D1L.mp4', '54D0L.mp4', '54D1R.mp4', '54D0R.mp4']
# ############################################################
# Subject 55 : ['55D1L.mp4', '55D2R.mp4', '55D0R.mp4', '55D0L.mp4', '55D1R.mp4', '55D2L.mp4']
# ############################################################
# Subject 56 : ['56D0L.mp4', '56D0R.mp4', '56D1R.mp4', '56D1L.mp4']
# ############################################################
# Subject 57 : ['57D3R.mp4', '57D2R.mp4', '57D0L.mp4', '57D4L.mp4', '57D0R.mp4', '57D3L.mp4', '57D1L.mp4', '57D1R.mp4', '57D4R.mp4', '57D2L.mp4']
# ############################################################
# Subject 58 : ['58D0L.mp4', '58D3R.mp4', '58D0R.mp4', '58D2R.mp4', '58D2L.mp4', '58D4L.mp4', '58D3L.mp4', '58D4R.mp4']
# ############################################################
# Subject 59 : ['59D0L.mp4', '59D1L.mp4', '59D0R.mp4', '59D2R.mp4', '59D1R.mp4', '59d2L.mp4', '59D3L.mp4', '59D3R.mp4']
# ############################################################
# Subject 6 : ['6D1L.mp4', '6D2L.mp4', '6D2R.mp4', '6D0L.mp4', '6D1R.mp4', '6D0R.mp4']
# ############################################################
# Subject 60 : ['60D1R.mp4', '60D2R.mp4', '60D1L.mp4', '60D5R.mp4', '60D0R.mp4', '60D2L.mp4', '60D0L.mp4', '60D5L.mp4']
# ############################################################
# Subject 61 : ['61D0L.mp4', '61D0R.mp4', '61D1R.mp4', '61D1L.mp4']
# ############################################################
# Subject 62 : ['62D0R.mp4', '62D4R.mp4', '62D5R.mp4', '62D4L.mp4', '62D3L.mp4', '62D5L.mp4', '62D0L.mp4', '62D3R2.mp4', '62D3R.mp4']
# ############################################################
# Subject 63 : ['63D1R.mp4', '63D2L.mp4', '63D0R.mp4', '63D1L.mp4', '63D2R.mp4', '63D0L.mp4']
# ############################################################
# Subject 64 : ['64D3L.mp4', '64D0R.mp4', '64D4R.mp4', '64D4L.mp4', '64D3R.mp4', '64D0l.mp4', '64D2L.mp4', '64D2R.mp4', '64D1L.mp4', '64D1R.mp4']
# ############################################################
# Subject 65 : ['65D0L.mp4', '65D0R.mp4', '65D1L.mp4', '65D1R.mp4']
# ############################################################
# Subject 66 : ['66D0R(1).mp4', '66D3R.mp4', '66D2R.mp4', '66D3L.mp4', '66D1R.mp4', '66D1L.mp4', '66D0R.mp4', '66D2L.mp4', '66D0L.mp4']
# ############################################################
# Subject 67 : ['67D0L.mp4', '67D2R.mp4', '67D0R.mp4', '67D2L.mp4']
# ############################################################
# Subject 68 : ['68D0L.mp4', '68D3R.mp4', '68D0R.mp4', '68D3L.mp4']
# ############################################################
# Subject 69 : ['69D2L.mp4', '69D1L.mp4', '69D0L.mp4', '69D1R.mp4', '69D0R.mp4', '69D2R.mp4']
# ############################################################
# Subject 7 : ['7D0L.mp4', '7D1R.mp4', '7D1L.mp4', '7D0R.mp4']
# ############################################################
# Subject 70 : ['70D1L.mp4', '70D0L.mp4', '70D0R.mp4', '70D1R.mp4', '70D2R.mp4', '70D2L.mp4']
# ############################################################
# Subject 71 : ['71D1R.mp4', '71D0L.mp4', '71D1L.mp4', '71D0R.mp4']
# ############################################################
# Subject 8 : ['8D2R.mp4', '8D1R.mp4', '8D2L.mp4', '8D1L.mp4', '8D0R.mp4', '8D0L.mp4']
# ############################################################
# Subject 9 : ['9D3R.mp4', '9D0L.mp4', '9D0R.mp4', '9D1R.mp4', '9D3L.mp4', '9D1L.mp4']

# %%
print('Total Videos:', sum(list_video_counter))
print('Mean Videos :', np.mean(list_video_counter))
print('Max Videos  :', np.max(list_video_counter))
print('Min Videos  :', np.min(list_video_counter))
# Out:
# Total Videos: 425
# Mean Videos : 5.985915492957746
# Max Videos  : 10
# Min Videos  : 2

# %% [markdown]
# # Get video duration

# %%
list_video_duration = []
list_video_frames = []
list_video_fps = []

for folder in folders:
    folder_path = os.path.join(directory_path, folder)
    
    subject = folder.split('.')[0]
    
    # Get the list of files and folders in the directory
    contents = list_directory_contents(folder_path)
    contents = [x for x in contents if ':Zone.Identifier' not in x]

    for content in contents:
        video_path = os.path.join(folder_path, content)
        duration, frame_count, fps = get_video_duration(video_path)
        list_video_duration.append(duration)
        list_video_frames.append(frame_count)
        list_video_fps.append(fps)
        
        print(f'Subject {subject} - {content} - Duration: {round(duration, 3)}s - {frame_count} frames - FPS {round(fps, 3)}')
# Out:
# Subject 1 - 1D0L.mp4 - Duration: 10.0s - 299 frames - FPS 29.9
# Subject 1 - 1D0R.mp4 - Duration: 6.8s - 204 frames - FPS 30.0
# Subject 10 - 10D2L.mp4 - Duration: 14.867s - 446 frames - FPS 30.0
# Subject 10 - 10D1R.mp4 - Duration: 10.567s - 316 frames - FPS 29.906
# Subject 10 - 10D1L.mp4 - Duration: 11.067s - 332 frames - FPS 30.0
# Subject 10 - 10D0R.mp4 - Duration: 12.667s - 370 frames - FPS 29.211
# Subject 10 - 10D2R.mp4 - Duration: 14.167s - 425 frames - FPS 30.0
# Subject 10 - 10D0L.mp4 - Duration: 10.9s - 327 frames - FPS 30.0
# Subject 11 - 11D0L.mp4 - Duration: 11.2s - 336 frames - FPS 30.0
# Subject 11 - 11D2R.mp4 - Duration: 8.233s - 247 frames - FPS 30.0
# Subject 11 - 11D2L.mp4 - Duration: 9.233s - 276 frames - FPS 29.892
# Subject 11 - 11D1R.mp4 - Duration: 7.667s - 230 frames - FPS 30.0
# Subject 11 - 11D1L.mp4 - Duration: 9.0s - 269 frames - FPS 29.889
# Subject 11 - 11D0R.mp4 - Duration: 11.633s - 349 frames - FPS 30.0
# Subject 12 - 12D0L.mp4 - Duration: 10.2s - 306 frames - FPS 30.0
# Subject 12 - 12D0R.mp4 - Duration: 8.933s - 267 frames - FPS 29.888
# Subject 13 - 13D1L.mp4 - Duration: 12.0s - 359 frames - FPS 29.917
# Subject 13 - 13D0L.mp4 - Duration: 11.867s - 355 frames - FPS 29.916
# Subject 13 - 13D2L.mp4 - Duration: 12.067s - 361 frames - FPS 29.917
# Subject 13 - 13D5L.mp4 - Duration: 9.633s - 287 frames - FPS 29.793
# Subject 14 - 14D1L.mp4 - Duration: 6.533s - 196 frames - FPS 30.0
# Subject 14 - 14D1R.mp4 - Duration: 13.1s - 393 frames - FPS 30.0
# Subject 8 - 8D1R.mp4 - Duration: 10.1s - 303 frames - FPS 30.0
# Subject 8 - 8D2L.mp4 - Duration: 16.457s - 494 frames - FPS 30.018
# Subject 8 - 8D1L.mp4 - Duration: 9.9s - 297 frames - FPS 30.0
# Subject 8 - 8D0R.mp4 - Duration: 15.533s - 466 frames - FPS 30.0
# Subject 8 - 8D0L.mp4 - Duration: 14.633s - 439 frames - FPS 30.0
# Subject 9 - 9D3R.mp4 - Duration: 17.067s - 512 frames - FPS 30.0
# Subject 9 - 9D0L.mp4 - Duration: 17.123s - 514 frames - FPS 30.018
# Subject 9 - 9D0R.mp4 - Duration: 16.9s - 507 frames - FPS 30.0
# Subject 9 - 9D1R.mp4 - Duration: 12.8s - 384 frames - FPS 30.0
# Subject 9 - 9D3L.mp4 - Duration: 17.2s - 516 frames - FPS 30.0
# Subject 9 - 9D1L.mp4 - Duration: 11.167s - 333 frames - FPS 29.821

# %%
print('Total Videos:', round(sum(list_video_duration), 3), 's')
print('Mean Videos :', round(np.mean(list_video_duration), 3), 's')
print('Median Videos :', round(np.median(list_video_duration), 3), 's')
print('Max Videos  :', round(np.max(list_video_duration), 3), 's')
print('Min Videos  :', round(np.min(list_video_duration), 3), 's')
print()
print('Total Frames:', round(sum(list_video_frames), 3))
print('Mean Frames :', round(np.mean(list_video_frames), 3))
print('Median Frames :', round(np.median(list_video_frames), 3))
print('Max Frames  :', round(np.max(list_video_frames), 3))
print('Min Frames  :', round(np.min(list_video_frames), 3))
# Out:
# Total Videos: 8237.08 s
# Mean Videos : 19.381 s
# Median Videos : 20.033 s
# Max Videos  : 34.766 s
# Min Videos  : 4.633 s
#
# Total Frames: 246972
# Mean Frames : 581.111
# Median Frames : 600.0
# Max Frames  : 1043
# Min Frames  : 139

# %% [markdown]
# # Extract frames as video to be saved as images

# %%
folders
# Out:
# ['1. Subject 1',
#  '10. Subject 10',
#  '11. Subject 11',
#  '12. Subject 12',
#  '13. Subject 13',
#  '14. Subject 14',
#  '15. Subject 15',
#  '16. Subject 16',
#  '17. Subject 17',
#  '18. Subject 18',
#  '19. Subject 19',
#  '2. Subject 2',
#  '20. Subject 20',
#  '21. Subject 21',
#  '22. Subject 22',
#  '23. Subject 23',
#  '24. Subject 24',
#  '25. Subject 25',
#  '26. Subject 26',
#  '27. Subject 27',
#  '28. Subject 28',
#  '29. Subject 29',
#  '3. Subject 3',
#  '30. Subject 30',
#  '31. Subject 31',
#  '32. Subject 32',
#  '33. Subject 33',
#  '34. Subject 34',
#  '35. Subject 35',
#  '36. Subject 36',
#  '37. Subject 37',
#  '38. Subject 38',
#  '39. Subject 39',
#  '4. Subject 4',
#  '40. Subject 40',
#  '41. Subject 41',
#  '42. Subject 42',
#  '43. Subject 43',
#  '44. Subject 44',
#  '45. Subject 45',
#  '46. Subject 46',
#  '47. Subject 47',
#  '48. Subject 48',
#  '49. Subject 49',
#  '5. Subject 5',
#  '50. Subject 50',
#  '51. Subject 51',
#  '52. Subject 52',
#  '53. Subject 53',
#  '54. Subject 54',
#  '55. Subject 55',
#  '56. Subject 56',
#  '57. Subject 57',
#  '58. Subject 58',
#  '59. Subject 59',
#  '6. Subject 6',
#  '60. Subject 60',
#  '61. Subject 61',
#  '62. Subject 62',
#  '63. Subject 63',
#  '64. Subject 64',
#  '65. Subject 65',
#  '66. Subject 66',
#  '67. Subject 67',
#  '68. Subject 68',
#  '69. Subject 69',
#  '7. Subject 7',
#  '70. Subject 70',
#  '71. Subject 71',
#  '8. Subject 8',
#  '9. Subject 9']

# %%
df_results = []

# folders = ['71. Subject 71',]

list_algorithm = [
    '', 
    # '_colmap', 
    # '_mve', 
    # '_vggsfm'
    ]

# list_scale_percent = [100, 50]
# list_max_frames = [30, 45, 60, 75]

# list_scale_percent = [50]
# list_scale_percent = [25]
# list_scale_percent = [50]
# list_max_frames = [60] # Total no of frame
# list_max_frames = [5] # No of frame per second

list_scale_percent = [100]
list_max_frames = [5] # No of frame per second

for scale_percent, max_frames in itertools.product(list_scale_percent, list_max_frames):
    for folder in folders:
        folder_path = os.path.join(directory_path, folder)
        
        subject = folder.split('.')[0]
        
        # Get the list of files and folders in the directory
        contents = list_directory_contents(folder_path)
        contents = [x for x in contents if ':Zone.Identifier' not in x]
        
        print()
        print('#'*60)
        print('Subject', subject)
        print(folder_path)
        print(contents)

        
        for algorithm in list_algorithm:
            print(algorithm)
            
            directory_save_path = f'/home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_Frames_input/image_input{algorithm}_{scale_percent}_{max_frames}'
            folder_save_path = os.path.join(directory_save_path, subject)
            
            # Create the output folder if it doesn't exist
            if not os.path.exists(folder_save_path):
                os.makedirs(folder_save_path)

            for content in contents:

                # Input
                video_path = os.path.join(folder_path, content)  # Replace with the actual path to the video file
                # Output
                if algorithm in ['']:
                    folder_save_path_video = os.path.join(folder_save_path, content.replace('.mp4', ''))
                elif algorithm in ['_colmap', '_mve', '_vggsfm']:
                    folder_save_path_video = os.path.join(folder_save_path, content.replace('.mp4', ''), 'images')
                
                # Extract frames from the video
                # Set max frames
                duration, frame_count, fps = get_video_duration(video_path)
                saved_frame_count = extract_frames(video_path, folder_save_path_video, fps, scale_percent, max_frames)

                print(f'{content.replace('.mp4', '')} - Scale: {scale_percent} - Max Frame: {max_frames} - Duration: {round(duration, 3)}s - No Frames: {saved_frame_count}')
                # print(f'Duration: {duration}s - Max Frame Set: {max_frames}')
                
                results = [folder, 
                        algorithm, 
                        scale_percent,
                        max_frames,
                        content.replace('.mp4', ''), 
                        saved_frame_count,
                        duration, frame_count, fps]
                df_results.append(results)

columns = ['Subject', 'Algorithm', 'Scale', 'Max_Frames', 'Video', 'Frames_Saved', 'Duration', 'Frame_Count', 'FPS']

df_results = pd.DataFrame(df_results, columns=columns)
directory_save_path = f'/home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE_Frames_input/'
df_results.to_csv(os.path.join(directory_save_path, 'data_summary.csv'), index=False)
# Out:
# ############################################################
# Subject 1
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/1. Subject 1
# ['1D0L.mp4', '1D0R.mp4']
#
# 1D0L - Scale: 100 - Max Frame: 5 - Duration: 10.0s - No Frames: 50
# 1D0R - Scale: 100 - Max Frame: 5 - Duration: 6.8s - No Frames: 30
#
# ############################################################
# Subject 10
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/10. Subject 10
# ['10D2L.mp4', '10D1R.mp4', '10D1L.mp4', '10D0R.mp4', '10D2R.mp4', '10D0L.mp4']
#
# 10D2L - Scale: 100 - Max Frame: 5 - Duration: 14.867s - No Frames: 70
# 10D1R - Scale: 100 - Max Frame: 5 - Duration: 10.567s - No Frames: 50
# 10D1L - Scale: 100 - Max Frame: 5 - Duration: 11.067s - No Frames: 55
# 10D0R - Scale: 100 - Max Frame: 5 - Duration: 12.667s - No Frames: 60
# 10D2R - Scale: 100 - Max Frame: 5 - Duration: 14.167s - No Frames: 70
# 10D0L - Scale: 100 - Max Frame: 5 - Duration: 10.9s - No Frames: 50
#
# ############################################################
# Subject 11
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/11. Subject 11
# ['11D0L.mp4', '11D2R.mp4', '11D2L.mp4', '11D1R.mp4', '11D1L.mp4', '11D0R.mp4']
#
# 11D0L - Scale: 100 - Max Frame: 5 - Duration: 11.2s - No Frames: 55
# 11D2R - Scale: 100 - Max Frame: 5 - Duration: 8.233s - No Frames: 40
# 11D2L - Scale: 100 - Max Frame: 5 - Duration: 9.233s - No Frames: 45
# 11D1R - Scale: 100 - Max Frame: 5 - Duration: 7.667s - No Frames: 35
# 11D1L - Scale: 100 - Max Frame: 5 - Duration: 9.0s - No Frames: 45
# 11D0R - Scale: 100 - Max Frame: 5 - Duration: 11.633s - No Frames: 55
#
# ############################################################
# Subject 12
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/12. Subject 12
# ['12D0L.mp4', '12D0R.mp4']
#
# 12D0L - Scale: 100 - Max Frame: 5 - Duration: 10.2s - No Frames: 50
# 12D0R - Scale: 100 - Max Frame: 5 - Duration: 8.933s - No Frames: 45
#
# ############################################################
# Subject 13
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/13. Subject 13
# ['13D1L.mp4', '13D0L.mp4', '13D2L.mp4', '13D5L.mp4']
#
# 13D1L - Scale: 100 - Max Frame: 5 - Duration: 12.0s - No Frames: 60
# 13D0L - Scale: 100 - Max Frame: 5 - Duration: 11.867s - No Frames: 60
# 13D2L - Scale: 100 - Max Frame: 5 - Duration: 12.067s - No Frames: 60
# 13D5L - Scale: 100 - Max Frame: 5 - Duration: 9.633s - No Frames: 45
#
# ############################################################
# Subject 14
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/14. Subject 14
# ['14D1L.mp4', '14D1R.mp4', '14D0R.mp4', '14D0L.mp4']
#
# 14D1L - Scale: 100 - Max Frame: 5 - Duration: 6.533s - No Frames: 30
# 14D1R - Scale: 100 - Max Frame: 5 - Duration: 13.1s - No Frames: 65
# 14D0R - Scale: 100 - Max Frame: 5 - Duration: 12.5s - No Frames: 60
# 14D0L - Scale: 100 - Max Frame: 5 - Duration: 12.067s - No Frames: 60
#
# ############################################################
# Subject 15
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/15. Subject 15
# ['15D2L.mp4', '15D1L.mp4', '15D0R.mp4', '15D0L.mp4', '15D1R.mp4', '15D2R.mp4']
#
# 15D1L - Scale: 100 - Max Frame: 5 - Duration: 17.767s - No Frames: 85
# 15D0R - Scale: 100 - Max Frame: 5 - Duration: 4.833s - No Frames: 20
# 15D0L - Scale: 100 - Max Frame: 5 - Duration: 10.833s - No Frames: 55
# 15D1R - Scale: 100 - Max Frame: 5 - Duration: 20.5s - No Frames: 100
# 15D2R - Scale: 100 - Max Frame: 5 - Duration: 16.433s - No Frames: 80
#
# ############################################################
# Subject 16
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/2. Subject 2
# ['2D4R.mp4', '2D0R.mp4', '2D5R.mp4', '2D0L.mp4', '2D4L.mp4', '2D5L.mp4']
#
# 2D4R - Scale: 100 - Max Frame: 5 - Duration: 15.233s - No Frames: 75
# 2D0R - Scale: 100 - Max Frame: 5 - Duration: 18.933s - No Frames: 90
# 2D5R - Scale: 100 - Max Frame: 5 - Duration: 19.1s - No Frames: 95
# 2D0L - Scale: 100 - Max Frame: 5 - Duration: 16.1s - No Frames: 80
# 2D4L - Scale: 100 - Max Frame: 5 - Duration: 14.8s - No Frames: 75
# 2D5L - Scale: 100 - Max Frame: 5 - Duration: 17.5s - No Frames: 85
#
# ############################################################
# Subject 20
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/20. Subject 20
# ['20D0L.mp4', '20D3L.mp4', '20D2L.mp4', '20D1L.mp4']
#
# 20D0L - Scale: 100 - Max Frame: 5 - Duration: 18.067s - No Frames: 90
# 20D3L - Scale: 100 - Max Frame: 5 - Duration: 24.233s - No Frames: 120
# 20D2L - Scale: 100 - Max Frame: 5 - Duration: 14.867s - No Frames: 70
# 20D1L - Scale: 100 - Max Frame: 5 - Duration: 25.033s - No Frames: 125
#
# ############################################################
# Subject 21
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/21. Subject 21
# ['21D0R.mp4', '21D0L.mp4']
#
# 21D0R - Scale: 100 - Max Frame: 5 - Duration: 15.4s - No Frames: 75
# 21D0L - Scale: 100 - Max Frame: 5 - Duration: 20.967s - No Frames: 100
#
# ############################################################
# Subject 22
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/22. Subject 22
# ['22D2R.mp4', '22D1L.mp4', '22D0R.mp4', '22D2L.mp4', '22D0L.mp4', '22D1R.mp4', '22D0L_2.mp4']
#
# 22D2R - Scale: 100 - Max Frame: 5 - Duration: 20.3s - No Frames: 100
# 22D1L - Scale: 100 - Max Frame: 5 - Duration: 25.167s - No Frames: 125
# 22D0R - Scale: 100 - Max Frame: 5 - Duration: 17.6s - No Frames: 90
# 22D2L - Scale: 100 - Max Frame: 5 - Duration: 23.0s - No Frames: 115
# 22D0L - Scale: 100 - Max Frame: 5 - Duration: 15.633s - No Frames: 75
# 22D1R - Scale: 100 - Max Frame: 5 - Duration: 27.466s - No Frames: 140
# 22D0L_2 - Scale: 100 - Max Frame: 5 - Duration: 15.767s - No Frames: 75
#
# ############################################################
# Subject 23
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/23. Subject 23
# ['23D1L.mp4', '23D0L.mp4', '23D1R.mp4', '23D0R.mp4']
#
# 23D1L - Scale: 100 - Max Frame: 5 - Duration: 21.467s - No Frames: 105
# 23D0L - Scale: 100 - Max Frame: 5 - Duration: 20.2s - No Frames: 100
# 23D1R - Scale: 100 - Max Frame: 5 - Duration: 26.033s - No Frames: 130
# 23D0R - Scale: 100 - Max Frame: 5 - Duration: 17.933s - No Frames: 90
#
# ############################################################
# Subject 24
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/28. Subject 28
# ['28D3L.mp4', '28D2R.mp4', '28D0L.mp4', '28D1L.mp4', '28D1R.mp4', '28D3R.mp4', '28D2L.mp4', '28D0R.mp4']
#
# 28D3L - Scale: 100 - Max Frame: 5 - Duration: 27.866s - No Frames: 135
# 28D2R - Scale: 100 - Max Frame: 5 - Duration: 24.2s - No Frames: 120
# 28D0L - Scale: 100 - Max Frame: 5 - Duration: 22.61s - No Frames: 115
# 28D1L - Scale: 100 - Max Frame: 5 - Duration: 22.633s - No Frames: 110
# 28D1R - Scale: 100 - Max Frame: 5 - Duration: 23.4s - No Frames: 115
# 28D3R - Scale: 100 - Max Frame: 5 - Duration: 20.1s - No Frames: 100
# 28D2L - Scale: 100 - Max Frame: 5 - Duration: 24.8s - No Frames: 120
# 28D0R - Scale: 100 - Max Frame: 5 - Duration: 17.267s - No Frames: 85
#
# ############################################################
# Subject 29
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/29. Subject 29
# ['29D0L.mp4', '29D1L.mp4', '29D1R.mp4', '29D0R.mp4']
#
# 29D0L - Scale: 100 - Max Frame: 5 - Duration: 20.333s - No Frames: 100
# 29D1L - Scale: 100 - Max Frame: 5 - Duration: 12.643s - No Frames: 65
# 29D1R - Scale: 100 - Max Frame: 5 - Duration: 10.6s - No Frames: 50
# 29D0R - Scale: 100 - Max Frame: 5 - Duration: 22.733s - No Frames: 110
#
# ############################################################
# Subject 3
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/3. Subject 3
# ['3D3R.mp4', '3D0L.mp4', '3D2R.mp4', '3D2L.mp4', '3D1R.mp4', '3D1L.mp4', '3D3L.mp4', '3D0R.mp4']
#
# 3D3R - Scale: 100 - Max Frame: 5 - Duration: 14.3s - No Frames: 70
# 3D0L - Scale: 100 - Max Frame: 5 - Duration: 12.967s - No Frames: 65
# 3D2R - Scale: 100 - Max Frame: 5 - Duration: 16.333s - No Frames: 80
# 3D2L - Scale: 100 - Max Frame: 5 - Duration: 17.167s - No Frames: 85
# 3D1R - Scale: 100 - Max Frame: 5 - Duration: 17.233s - No Frames: 85
# 3D1L - Scale: 100 - Max Frame: 5 - Duration: 17.533s - No Frames: 85
# 3D3L - Scale: 100 - Max Frame: 5 - Duration: 15.167s - No Frames: 75
# 3D0R - Scale: 100 - Max Frame: 5 - Duration: 14.1s - No Frames: 70
#
# ############################################################
# Subject 30
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/30. Subject 30
# ['30D3R.mp4', '30D3L.mp4', '30D0L.mp4', '30D0R.mp4']
#
# 30D3R - Scale: 100 - Max Frame: 5 - Duration: 24.433s - No Frames: 120
# 30D3L - Scale: 100 - Max Frame: 5 - Duration: 22.2s - No Frames: 110
# 30D0L - Scale: 100 - Max Frame: 5 - Duration: 23.033s - No Frames: 115
# 30D0R - Scale: 100 - Max Frame: 5 - Duration: 24.5s - No Frames: 120
#
# ############################################################
# Subject 31
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/31. Subject 31
# ['31D3L.mp4', '31D0L.mp4', '31D0R.mp4', '31D4L.mp4', '31D1R.mp4', '31D1L.mp4', '31D3R.mp4', '31D2L.mp4', '31D4R.mp4', '31D2R.mp4']
#
# 31D3L - Scale: 100 - Max Frame: 5 - Duration: 20.343s - No Frames: 105
# 31D0L - Scale: 100 - Max Frame: 5 - Duration: 14.057s - No Frames: 70
# 31D0R - Scale: 100 - Max Frame: 5 - Duration: 18.4s - No Frames: 90
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/44. Subject 44
# ['44D0L.mp4', '44D3L.mp4', '44D3R.mp4', '44D2R.mp4', '44D4R.mp4', '44D2L.mp4', '44D1R.mp4', '44D0R.mp4', '44D4L.mp4', '44D1L.mp4']
#
# 44D0L - Scale: 100 - Max Frame: 5 - Duration: 24.867s - No Frames: 120
# 44D3L - Scale: 100 - Max Frame: 5 - Duration: 19.133s - No Frames: 95
# 44D3R - Scale: 100 - Max Frame: 5 - Duration: 18.3s - No Frames: 90
# 44D2R - Scale: 100 - Max Frame: 5 - Duration: 18.4s - No Frames: 90
# 44D4R - Scale: 100 - Max Frame: 5 - Duration: 20.3s - No Frames: 100
# 44D2L - Scale: 100 - Max Frame: 5 - Duration: 23.567s - No Frames: 115
# 44D1R - Scale: 100 - Max Frame: 5 - Duration: 21.467s - No Frames: 105
# 44D0R - Scale: 100 - Max Frame: 5 - Duration: 18.433s - No Frames: 90
# 44D4L - Scale: 100 - Max Frame: 5 - Duration: 18.667s - No Frames: 90
# 44D1L - Scale: 100 - Max Frame: 5 - Duration: 24.667s - No Frames: 125
#
# ############################################################
# Subject 45
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/45. Subject 45
# ['45D2L.mp4', '45D5R.mp4', '45D5L.mp4', '45D2R.mp4', '45D1R.mp4', '45D0L.mp4', '45D1L.mp4', '45D0R.mp4']
#
# 45D2L - Scale: 100 - Max Frame: 5 - Duration: 16.367s - No Frames: 80
# 45D5R - Scale: 100 - Max Frame: 5 - Duration: 17.867s - No Frames: 90
# 45D5L - Scale: 100 - Max Frame: 5 - Duration: 23.467s - No Frames: 120
# 45D2R - Scale: 100 - Max Frame: 5 - Duration: 16.7s - No Frames: 80
# 45D1R - Scale: 100 - Max Frame: 5 - Duration: 21.567s - No Frames: 105
# 45D0L - Scale: 100 - Max Frame: 5 - Duration: 18.0s - No Frames: 90
# 45D1L - Scale: 100 - Max Frame: 5 - Duration: 19.867s - No Frames: 95
# 45D0R - Scale: 100 - Max Frame: 5 - Duration: 20.633s - No Frames: 100
#
# ############################################################
# Subject 46
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/46. Subject 46
# ['46D0L.mp4', '46D0R.mp4']
#
# 46D0L - Scale: 100 - Max Frame: 5 - Duration: 20.767s - No Frames: 105
# 46D0R - Scale: 100 - Max Frame: 5 - Duration: 23.667s - No Frames: 115
#
# ############################################################
# Subject 47
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/47. Subject 47
# ['47D1R.mp4', '47D1L.mp4', '47D4L.mp4', '47D0L.mp4', '47D3R.mp4', '47D3L.mp4', '47D0R.mp4', '47D2L.mp4', '47D4R.mp4', '47D2R.mp4']
#
# 47D1R - Scale: 100 - Max Frame: 5 - Duration: 18.433s - No Frames: 95
# 47D1L - Scale: 100 - Max Frame: 5 - Duration: 17.367s - No Frames: 85
# 47D4L - Scale: 100 - Max Frame: 5 - Duration: 11.257s - No Frames: 55
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/50. Subject 50
# ['50D4L.mp4', '50D0L.mp4', '50D1R.mp4', '50D1L.mp4', '50D3L.mp4', '50D0R.mp4', '50D4R.mp4', '50D2R.mp4', '50D2L.mp4', '50D3R.mp4']
#
# 50D4L - Scale: 100 - Max Frame: 5 - Duration: 20.2s - No Frames: 100
# 50D0L - Scale: 100 - Max Frame: 5 - Duration: 23.733s - No Frames: 115
# 50D1R - Scale: 100 - Max Frame: 5 - Duration: 20.533s - No Frames: 100
# 50D1L - Scale: 100 - Max Frame: 5 - Duration: 22.333s - No Frames: 110
# 50D3L - Scale: 100 - Max Frame: 5 - Duration: 20.1s - No Frames: 100
# 50D0R - Scale: 100 - Max Frame: 5 - Duration: 24.667s - No Frames: 120
# 50D4R - Scale: 100 - Max Frame: 5 - Duration: 18.667s - No Frames: 90
# 50D2R - Scale: 100 - Max Frame: 5 - Duration: 19.667s - No Frames: 95
# 50D2L - Scale: 100 - Max Frame: 5 - Duration: 17.767s - No Frames: 90
# 50D3R - Scale: 100 - Max Frame: 5 - Duration: 20.667s - No Frames: 100
#
# ############################################################
# Subject 51
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/51. Subject 51
# ['51D0L.mp4', '51D0R.mp4']
#
# 51D0L - Scale: 100 - Max Frame: 5 - Duration: 23.367s - No Frames: 120
# 51D0R - Scale: 100 - Max Frame: 5 - Duration: 20.1s - No Frames: 100
#
# ############################################################
# Subject 52
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/52. Subject 52
# ['52D1L.mp4', '52D0R.mp4', '52D2L.mp4', '52D2R.mp4', '52D0L.mp4', '52D1R.mp4']
#
# 52D1L - Scale: 100 - Max Frame: 5 - Duration: 8.733s - No Frames: 40
# 52D0R - Scale: 100 - Max Frame: 5 - Duration: 9.133s - No Frames: 45
# 52D2L - Scale: 100 - Max Frame: 5 - Duration: 8.567s - No Frames: 40
# 52D2R - Scale: 100 - Max Frame: 5 - Duration: 8.767s - No Frames: 45
# 52D0L - Scale: 100 - Max Frame: 5 - Duration: 8.333s - No Frames: 40
# 52D1R - Scale: 100 - Max Frame: 5 - Duration: 9.467s - No Frames: 45
#
# ############################################################
# Subject 53
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/53. Subject 53
# ['53D0L.mp4', '53D1R.mp4', '53D1L.mp4', '53D2L.mp4', '53D2R.mp4', '53D0R.mp4']
#
# 53D0L - Scale: 100 - Max Frame: 5 - Duration: 10.733s - No Frames: 55
# 53D1R - Scale: 100 - Max Frame: 5 - Duration: 16.033s - No Frames: 80
# 53D1L - Scale: 100 - Max Frame: 5 - Duration: 17.767s - No Frames: 90
# 53D2L - Scale: 100 - Max Frame: 5 - Duration: 20.6s - No Frames: 100
# 53D2R - Scale: 100 - Max Frame: 5 - Duration: 25.933s - No Frames: 125
# 53D0R - Scale: 100 - Max Frame: 5 - Duration: 10.8s - No Frames: 50
#
# ############################################################
# Subject 54
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/54. Subject 54
# ['54D1L.mp4', '54D0L.mp4', '54D1R.mp4', '54D0R.mp4']
#
# 54D1L - Scale: 100 - Max Frame: 5 - Duration: 22.967s - No Frames: 115
# 54D0L - Scale: 100 - Max Frame: 5 - Duration: 23.133s - No Frames: 115
# 54D1R - Scale: 100 - Max Frame: 5 - Duration: 24.067s - No Frames: 120
# 54D0R - Scale: 100 - Max Frame: 5 - Duration: 28.5s - No Frames: 140
#
# ############################################################
# Subject 55
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/62. Subject 62
# ['62D0R.mp4', '62D4R.mp4', '62D5R.mp4', '62D4L.mp4', '62D3L.mp4', '62D5L.mp4', '62D0L.mp4', '62D3R2.mp4', '62D3R.mp4']
#
# 62D0R - Scale: 100 - Max Frame: 5 - Duration: 24.733s - No Frames: 125
# 62D4R - Scale: 100 - Max Frame: 5 - Duration: 23.1s - No Frames: 115
# 62D5R - Scale: 100 - Max Frame: 5 - Duration: 10.2s - No Frames: 50
# 62D4L - Scale: 100 - Max Frame: 5 - Duration: 23.733s - No Frames: 115
# 62D3L - Scale: 100 - Max Frame: 5 - Duration: 24.967s - No Frames: 120
# 62D5L - Scale: 100 - Max Frame: 5 - Duration: 9.7s - No Frames: 50
# 62D0L - Scale: 100 - Max Frame: 5 - Duration: 24.033s - No Frames: 120
# 62D3R2 - Scale: 100 - Max Frame: 5 - Duration: 21.567s - No Frames: 105
# 62D3R - Scale: 100 - Max Frame: 5 - Duration: 4.633s - No Frames: 20
#
# ############################################################
# Subject 63
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/63. Subject 63
# ['63D1R.mp4', '63D2L.mp4', '63D0R.mp4', '63D1L.mp4', '63D2R.mp4', '63D0L.mp4']
#
# 63D1R - Scale: 100 - Max Frame: 5 - Duration: 24.533s - No Frames: 120
# 63D2L - Scale: 100 - Max Frame: 5 - Duration: 9.5s - No Frames: 45
# 63D0R - Scale: 100 - Max Frame: 5 - Duration: 20.833s - No Frames: 100
# 63D1L - Scale: 100 - Max Frame: 5 - Duration: 21.533s - No Frames: 110
# 63D2R - Scale: 100 - Max Frame: 5 - Duration: 9.9s - No Frames: 45
# 63D0L - Scale: 100 - Max Frame: 5 - Duration: 22.467s - No Frames: 115
#
# ############################################################
# Subject 64
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/64. Subject 64
# ['64D3L.mp4', '64D0R.mp4', '64D4R.mp4', '64D4L.mp4', '64D3R.mp4', '64D0l.mp4', '64D2L.mp4', '64D2R.mp4', '64D1L.mp4', '64D1R.mp4']
#
# 64D3L - Scale: 100 - Max Frame: 5 - Duration: 10.967s - No Frames: 50
# 64D0R - Scale: 100 - Max Frame: 5 - Duration: 9.6s - No Frames: 45
# 64D4R - Scale: 100 - Max Frame: 5 - Duration: 9.657s - No Frames: 45
# 64D4L - Scale: 100 - Max Frame: 5 - Duration: 8.89s - No Frames: 40
# 64D0l - Scale: 100 - Max Frame: 5 - Duration: 9.0s - No Frames: 45
# 64D2L - Scale: 100 - Max Frame: 5 - Duration: 9.667s - No Frames: 45
# 64D2R - Scale: 100 - Max Frame: 5 - Duration: 8.9s - No Frames: 45
# 64D1L - Scale: 100 - Max Frame: 5 - Duration: 9.7s - No Frames: 45
# 64D1R - Scale: 100 - Max Frame: 5 - Duration: 11.367s - No Frames: 55
#
# ############################################################
# Subject 65
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/65. Subject 65
# ['65D0L.mp4', '65D0R.mp4', '65D1L.mp4', '65D1R.mp4']
#
# 65D0L - Scale: 100 - Max Frame: 5 - Duration: 29.433s - No Frames: 145
# 65D0R - Scale: 100 - Max Frame: 5 - Duration: 24.5s - No Frames: 125
# 65D1L - Scale: 100 - Max Frame: 5 - Duration: 21.667s - No Frames: 105
# 65D1R - Scale: 100 - Max Frame: 5 - Duration: 26.233s - No Frames: 135
#
# ############################################################
# Subject 66
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/66. Subject 66
# ['66D0R(1).mp4', '66D3R.mp4', '66D2R.mp4', '66D3L.mp4', '66D1R.mp4', '66D1L.mp4', '66D0R.mp4', '66D2L.mp4', '66D0L.mp4']
#
# 66D0R(1) - Scale: 100 - Max Frame: 5 - Duration: 23.1s - No Frames: 115
# 66D3R - Scale: 100 - Max Frame: 5 - Duration: 10.5s - No Frames: 50
# 66D2R - Scale: 100 - Max Frame: 5 - Duration: 13.633s - No Frames: 65
# 66D3L - Scale: 100 - Max Frame: 5 - Duration: 10.167s - No Frames: 50
# 66D1R - Scale: 100 - Max Frame: 5 - Duration: 11.133s - No Frames: 55
# 66D1L - Scale: 100 - Max Frame: 5 - Duration: 12.067s - No Frames: 60
# 66D0R - Scale: 100 - Max Frame: 5 - Duration: 18.567s - No Frames: 90
# 66D2L - Scale: 100 - Max Frame: 5 - Duration: 11.233s - No Frames: 55
# 66D0L - Scale: 100 - Max Frame: 5 - Duration: 22.333s - No Frames: 115
#
# ############################################################
# Subject 67
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/67. Subject 67
# ['67D0L.mp4', '67D2R.mp4', '67D0R.mp4', '67D2L.mp4']
#
# 67D0L - Scale: 100 - Max Frame: 5 - Duration: 20.1s - No Frames: 100
# 67D2R - Scale: 100 - Max Frame: 5 - Duration: 10.7s - No Frames: 50
# 67D0R - Scale: 100 - Max Frame: 5 - Duration: 24.8s - No Frames: 120
# 67D2L - Scale: 100 - Max Frame: 5 - Duration: 9.867s - No Frames: 50
#
# ############################################################
# Subject 68
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/68. Subject 68
# ['68D0L.mp4', '68D3R.mp4', '68D0R.mp4', '68D3L.mp4']
#
# 68D0L - Scale: 100 - Max Frame: 5 - Duration: 20.233s - No Frames: 100
# 68D3R - Scale: 100 - Max Frame: 5 - Duration: 23.167s - No Frames: 115
# 68D0R - Scale: 100 - Max Frame: 5 - Duration: 24.433s - No Frames: 125
# 68D3L - Scale: 100 - Max Frame: 5 - Duration: 24.133s - No Frames: 120
#
# ############################################################
# Subject 69
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/69. Subject 69
# ['69D2L.mp4', '69D1L.mp4', '69D0L.mp4', '69D1R.mp4', '69D0R.mp4', '69D2R.mp4']
#
# 69D2L - Scale: 100 - Max Frame: 5 - Duration: 25.9s - No Frames: 130
# 69D1L - Scale: 100 - Max Frame: 5 - Duration: 22.4s - No Frames: 115
# 69D0L - Scale: 100 - Max Frame: 5 - Duration: 30.2s - No Frames: 150
# 69D1R - Scale: 100 - Max Frame: 5 - Duration: 25.2s - No Frames: 125
# 69D0R - Scale: 100 - Max Frame: 5 - Duration: 25.667s - No Frames: 130
# 69D2R - Scale: 100 - Max Frame: 5 - Duration: 21.467s - No Frames: 110
#
# ############################################################
# Subject 7
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/7. Subject 7
# ['7D0L.mp4', '7D1R.mp4', '7D1L.mp4', '7D0R.mp4']
#
# 7D0L - Scale: 100 - Max Frame: 5 - Duration: 16.367s - No Frames: 80
# 7D1R - Scale: 100 - Max Frame: 5 - Duration: 19.3s - No Frames: 95
# 7D1L - Scale: 100 - Max Frame: 5 - Duration: 14.867s - No Frames: 70
# 7D0R - Scale: 100 - Max Frame: 5 - Duration: 16.433s - No Frames: 80
#
# ############################################################
# Subject 70
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/70. Subject 70
# ['70D1L.mp4', '70D0L.mp4', '70D0R.mp4', '70D1R.mp4', '70D2R.mp4', '70D2L.mp4']
#
# 70D1L - Scale: 100 - Max Frame: 5 - Duration: 25.133s - No Frames: 125
# 70D0L - Scale: 100 - Max Frame: 5 - Duration: 22.7s - No Frames: 110
# 70D0R - Scale: 100 - Max Frame: 5 - Duration: 23.567s - No Frames: 115
# 70D1R - Scale: 100 - Max Frame: 5 - Duration: 21.033s - No Frames: 105
# 70D2R - Scale: 100 - Max Frame: 5 - Duration: 21.033s - No Frames: 105
# 70D2L - Scale: 100 - Max Frame: 5 - Duration: 22.2s - No Frames: 110
#
# ############################################################
# Subject 71
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/71. Subject 71
# ['71D1R.mp4', '71D0L.mp4', '71D1L.mp4', '71D0R.mp4']
#
# 71D1R - Scale: 100 - Max Frame: 5 - Duration: 10.267s - No Frames: 50
# 71D0L - Scale: 100 - Max Frame: 5 - Duration: 11.7s - No Frames: 55
# 71D1L - Scale: 100 - Max Frame: 5 - Duration: 11.667s - No Frames: 55
# 71D0R - Scale: 100 - Max Frame: 5 - Duration: 11.767s - No Frames: 55
#
# ############################################################
# Subject 8
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/8. Subject 8
# ['8D2R.mp4', '8D1R.mp4', '8D2L.mp4', '8D1L.mp4', '8D0R.mp4', '8D0L.mp4']
#
# 8D2R - Scale: 100 - Max Frame: 5 - Duration: 12.857s - No Frames: 60
# 8D1R - Scale: 100 - Max Frame: 5 - Duration: 10.1s - No Frames: 50
# 8D2L - Scale: 100 - Max Frame: 5 - Duration: 16.457s - No Frames: 80
# 8D1L - Scale: 100 - Max Frame: 5 - Duration: 9.9s - No Frames: 45
# 8D0R - Scale: 100 - Max Frame: 5 - Duration: 15.533s - No Frames: 75
# 8D0L - Scale: 100 - Max Frame: 5 - Duration: 14.633s - No Frames: 70
#
# ############################################################
# Subject 9
# /home/weiyanpeh/Git/SFM_Related/CADENCE/SHAPE/9. Subject 9
# ['9D3R.mp4', '9D0L.mp4', '9D0R.mp4', '9D1R.mp4', '9D3L.mp4', '9D1L.mp4']
#
# 9D3R - Scale: 100 - Max Frame: 5 - Duration: 17.067s - No Frames: 85
# 9D0L - Scale: 100 - Max Frame: 5 - Duration: 17.123s - No Frames: 85
# 9D0R - Scale: 100 - Max Frame: 5 - Duration: 16.9s - No Frames: 80
# 9D1R - Scale: 100 - Max Frame: 5 - Duration: 12.8s - No Frames: 60
# 9D3L - Scale: 100 - Max Frame: 5 - Duration: 17.2s - No Frames: 85
# 9D1L - Scale: 100 - Max Frame: 5 - Duration: 11.167s - No Frames: 55
